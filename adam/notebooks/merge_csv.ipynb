# %%
# libraries
import pandas as pd
import numpy as np
import time
import re

# %%
file_path = "../merged_t5_players.csv"

df = pd.read_csv(file_path)
# Entfernen von doppelten Einträgen basierend auf 'Player', 'Nation' und 'Pos'
df = df.drop_duplicates(subset=['Player', 'Nation', 'Pos'])
# Aktualisieren der CSV-Datei
df.to_csv(file_path, index=False)
print(f"Updated CSV file: {file_path}")
# Out:
# Updated CSV file: ../merged_t5_players.csv

# %%
origin_path = '../update_t5_players.csv'
misc_path = '../t5_leagues_players_misc.csv'
defense_path = '../t5_leagues_players_defense.csv'
possession_path = '../t5_leagues_players_possession.csv'
passing_path = '../t5_leagues_players_passing.csv'
shooting_path = '../t5_leagues_players_shooting.csv'
gca_path = '../t5_leagues_players_gca.csv'

# paths = [origin_path, misc_path, passing_path, defense_path, possession_path, shooting_path, gca_path]

# for path in paths:
  #  df = pd.read_csv(path)
   # 
    # Entfernen von doppelten Einträgen basierend auf 'Player', 'Nation' und 'Pos'
    # Beibehalten des Eintrags mit dem höchsten Wert in der Spalte '90s'
    #df = df.sort_values(by='90s', ascending=False).drop_duplicates(subset=['Player', 'Nation', 'Pos'], keep='first')
    
    # Speichern der aktualisierten CSV-Datei
    #df.to_csv(path, index=False)

    #print(f"Updated CSV file: {path}")

# %%
df = pd.read_csv(defense_path)
# insert a new row after TlkW and insert the TlkW divided by Tkl values
df['TlkW/Tkl'] = df['TklW'] / df['Tkl']
df.to_csv(defense_path, index=False)

# %%
import pandas as pd

# Pfade zu den CSV-Dateien


# Laden der CSV-Dateien
# Laden der CSV-Dateien
origin_players_df = pd.read_csv(origin_path)
defense_df = pd.read_csv(defense_path)
possession_df = pd.read_csv(possession_path)
misc_df = pd.read_csv(misc_path)
passing_df = pd.read_csv(passing_path)
gca_df = pd.read_csv(gca_path)
shooting_df = pd.read_csv(shooting_path)

# Spieler mit weniger als 250 Minuten ausschließen
origin_players_df = origin_players_df[origin_players_df['Min'] >= 250]

# Funktion zur Bereinigung der Positionsspalte
def clean_pos(pos):
    return pos.split(',')[0]

# Anwenden der Bereinigung der Positionsspalte
origin_players_df['Pos'] = origin_players_df['Pos'].apply(clean_pos)

# Funktion zum Hinzufügen von Präfixen und Nummerierung bei Kollisionen
def add_prefix_and_number(df, prefix, exclude_cols):
    col_count = {}
    new_cols = []
    for col in df.columns:
        if col not in exclude_cols:
            new_col = col
            if col in new_cols:
                if col not in col_count:
                    col_count[col] = 1
                col_count[col] += 1
                new_col = f"{prefix}_{col}_{col_count[col]}"
            elif col in combined_df.columns:
                new_col = f"{prefix}_{col}"
            new_cols.append(new_col)
        else:
            new_cols.append(col)
    df.columns = new_cols
    return df

# Initialisieren des kombinierten DataFrames mit origin_players_df
combined_df = origin_players_df[['Player', 'Nation', 'Age', 'Club', '90s', 'Min','Pos']]

# Liste der zu kombinierenden DataFrames mit ihren Präfixen
dataframes = [
    (passing_df, 'Pass'),
    (gca_df, 'GCA'),
    (shooting_df, 'Shoot'),
    (defense_df, 'Def'),
    (possession_df, 'Poss'),
    (misc_df, 'Misc')
]

# Zusammenführen der Daten
for df, prefix in dataframes:
    df = add_prefix_and_number(df, prefix, ['Player', 'Nation', 'Age', 'Club'])
    combined_df = pd.merge(combined_df, df, on=['Player', 'Nation', 'Age', 'Club'], how='left')

# Entfernen der zusätzlichen 'Pos' und '90s' Spalten
combined_df = combined_df.loc[:, ~combined_df.columns.duplicated()]

# Entfernen der 'Matches'-Spalten
combined_df = combined_df.loc[:, ~combined_df.columns.str.contains('Matches')]

# Speichern der kombinierten Daten in eine neue CSV-Datei
combined_df.to_csv('merged_t5_players_ultimate.csv', index=False)

print("Die CSV-Dateien wurden erfolgreich kombiniert und gespeichert.")
# Out:
# Die CSV-Dateien wurden erfolgreich kombiniert und gespeichert.

# %%
import pandas as pd

# Pfad zur CSV-Datei
file_path = 'merged_t5_players_ultimate.csv'

# Laden der CSV-Datei
df = pd.read_csv(file_path)

# Spalten filtern, um nur die gewünschten `90s` und `Pos` Werte zu behalten
filtered_columns = [col for col in df.columns if not any(col.startswith(prefix) for prefix in ['GCA_', 'Shoot_', 'Pass_', 'Misc_', 'Def_']) or col == '90s' or col == 'Pos']

# Zusätzlicher Filter für 'Pos' Werte, um nur die ursprüngliche `Pos` Spalte zu behalten
filtered_columns = [col for col in filtered_columns if not any(col.endswith(suffix) for suffix in ['_90s', '_Pos']) or col == '90s' or col == 'Pos' or col.startswith('Poss')]

# DataFrame mit den gefilterten Spalten erstellen
df_filtered = df[filtered_columns]

# Speichern der bereinigten CSV-Datei
df_filtered.to_csv('merged_t5_players_ultimate.csv', index=False)

print("Die CSV-Datei wurde erfolgreich bereinigt und gespeichert.")
# Out:
# Die CSV-Datei wurde erfolgreich bereinigt und gespeichert.

# %%
import pandas as pd

# Pfad zur CSV-Datei
file_path = 'merged_t5_players_ultimate.csv'

# Laden der CSV-Datei
df = pd.read_csv(file_path)

# Dictionary zur Umbenennung der Spalten
rename_columns = {
    'Player': 'Player',
    'Nation': 'Nation',
    'Age': 'Age',
    'Club': 'Club',
    '90s': '90 minutes played',
    'Min': 'Minutes played',
    'Pos': 'Position',
    'Cmp': 'Passes completed',
    'Att': 'Passes attempted',
    'Cmp%': 'Completed passes %',
    'TotDist': 'Total pass distance',
    'PrgDist': 'Progressive pass distance',
    'Cmp.1': 'Short passes completed',
    'Att.1': 'Short passes attempted',
    'Cmp%.1': 'Short passes completed %',
    'Cmp.2': 'Medium passes completed',
    'Att.2': 'Medium passes attempted',
    'Cmp%.2': 'Medium passes completed %',
    'Cmp.3': 'Long passes completed',
    'Att.3': 'Long passes attempted',
    'Cmp%.3': 'Long passes completed %',
    'Ast': 'Assists',
    'xAG': 'Expected Assisted Goals',
    'xA': 'Expected Assists',
    'A-xAG': 'A minus xAG',
    'KP': 'Key Passes',
    '1/3': 'Passes into final third',
    'PPA': 'Passes into penalty area',
    'CrsPA': 'Crosses into penalty area',
    'PrgP': 'Progressive passes',
    'SCA': 'Shot creating actions',
    'SCA90': 'Shot creating actions per 90',
    'PassLive': 'Shot creating actions by live-ball passes',
    'PassDead': 'Shot creating actions by dead-ball passes',
    'TO': 'Successful Take-Ons that led to a shot',
    'Sh': 'Shots that led to another shot attempt',
    'Fld': 'Fouls drawn that led to a shot attempt',
    'Def': 'Defensive actions that led to a shot attempt',
    'GCA': 'Goal creating actions',
    'GCA90': 'Goal creating actions per 90',
    'PassLive.1': 'Goal creating actions by live-ball passes',
    'PassDead.1': 'Goal creating actions by dead-ball passes',
    'TO.1': 'Successful Take-Ons that led to a goal',
    'Sh.1': 'Shots that led to another goal-scoring shot',
    'Fld.1': 'Fouls drawn that led to a goal',
    'Def.1': 'Defensive actions that led to a goal',
    'Gls': 'Goals',
    'SoT': 'Shots on target',
    'SoT%': 'Shots on target %',
    'Sh/90': 'Shots per 90',
    'SoT/90': 'Shots on target per 90',
    'G/Sh': 'Goals per shot',
    'G/SoT': 'Goals per shot on target',
    'Dist': 'Average shooting distance',
    'FK': 'Shots from free kicks',
    'PK': 'Penalty kicks made',
    'PKatt': 'Penalty kicks attempted',
    'xG': 'Expected Goals',
    'npxG': 'Non-penalty expected goals',
    'npxG/Sh': 'Non-penalty expected goals/Shot',
    'G-xG': 'Goals minus expected Goals',
    'np:G-xG': 'Non-penalty goals minus non-penalty expected Goals',
    'Tkl': 'Tackles',
    'TklW': 'Tackles won',
    'Def 3rd': 'Tackles in defensive 1/3',
    'Mid 3rd': 'Tackles in middle 1/3',
    'Att 3rd': 'Tackles in attacking 1/3',
    'Tkl.1': 'Dribblers tackled',
    'Tkl%': '% of dribblers tackled',
    'Lost': 'Challenges lost',
    'Blocks': 'Balls blocked',
    'Pass': 'Passes blocked',
    'Int': 'Interceptions',
    'Tkl+Int': 'Number of tackles and interceptions',
    'Clr': 'Clearances',
    'Err': 'Errors',
    'TlkW/Tkl': 'Tackles won %',
    'Touches': 'Touches',
    'Def Pen': 'Touches in defensive penalty area',
    'Poss_Def 3rd': 'Touches in defensive 1/3',
    'Poss_Mid 3rd': 'Touches in middle 1/3',
    'Poss_Att 3rd': 'Touches in attacking 1/3',
    'Att Pen': 'Touches in attacking penalty area',
    'Live': 'Live-ball touches',
    'Poss_Att': 'Take ons attempted',
    'Succ': 'Successful take ons',
    'Succ%': 'Successful take ons %',
    'Tkld': 'Times tackled during take on',
    'Tkld%': 'Times tackled during take on %',
    'Carries': 'Times ball carried with feet',
    'Poss_TotDist': 'Total moved ball distance',
    'Poss_PrgDist': 'Progressive moved ball distance',
    'PrgC': 'Progressive Carries',
    'Poss_1/3': 'Carries into final 1/3',
    'CPA': 'Carries into penalty area',
    'Mis': 'Miscontrols',
    'Dis': 'Dispossessed',
    'Rec': 'Passes received',
    'PrgR': 'Progressive Passes Received',
    'CrdY': 'Yellow cards',
    'CrdR': 'Red cards',
    '2CrdY': 'Second yellow card',
    'Fls': 'Fouls committed',
    'Off': 'Offsides',
    'Crs': 'Crosses',
    'PKwon': 'Penalty kicks won',
    'PKcon': 'Penalty kicks conceded',
    'OG': 'Own goals',
    'Recov': 'Recoveries',
    'Won': 'Aerial duels won',
    'Won%': 'Aerial duels won %'
}

# Entfernen der Spalten 'Poss_Pos' und 'Poss_90s'
df.drop(columns=['Poss_Pos', 'Poss_90s'], inplace=True)

# Umbenennen der Spalten
df.rename(columns=rename_columns, inplace=True)

# Speichern der bereinigten CSV-Datei
df.to_csv('op_players_list.csv', index=False)

print("Die CSV-Datei wurde erfolgreich bereinigt und gespeichert.")
# Out:
# Die CSV-Datei wurde erfolgreich bereinigt und gespeichert.

# %%
import pandas as pd

# Einlesen der CSV-Dateien
transfers_df = pd.read_csv('transfer_data_big6_2003_2023.csv')
performance_df = pd.read_csv('../op_players_list_with_percentiles_and_total_score.csv')

# Filtern der Ankünfte (Arrivals) mit einer Gebühr
arrivals_df = transfers_df[(transfers_df['Transfer'] == 'Arrival') & (transfers_df['Fee'] > 0)]

# Finden der Spieler, die sowohl in den Ankünfte der ersten CSV als auch in den Leistungsdaten der zweiten CSV vorhanden sind
merged_df = pd.merge(arrivals_df, performance_df, left_on=['Player', 'Club'], right_on=['Player', 'Club'], how='inner')

# Auswahl der relevanten Spalten und Umbenennung
final_df = merged_df[['Player', 'Club', 'Age', 'Fee', 'Total Score']]

# Speichern der finalen Daten in einer neuen CSV-Datei
final_df.to_csv('filtered_arrivals_with_additional_data.csv', index=False)

# Ausgabe der finalen Daten zur Überprüfung
print(final_df.to_string(index=False))
# Out:
#                    Player              Club  Age    Fee  Total Score
#          Jordan Henderson         Liverpool   28  18.00   859.117708
#          Daniel Sturridge         Liverpool   28  15.00   681.870955
#              Adam Lallana         Liverpool   30  31.00   678.129578
#              Dejan Lovren         Liverpool   29  25.30   500.475543
#           Roberto Firmino         Liverpool   26  41.00   754.856534
#                 Joe Gomez         Liverpool   21   4.90   665.217391
#                Sadio Mané         Liverpool   26  41.20   803.639342
#       Georginio Wijnaldum         Liverpool   27  27.50   697.077425
#           Virgil van Dijk         Liverpool   27  84.65   578.192935
#             Mohamed Salah         Liverpool   26  42.00   800.055429
#          Andrew Robertson         Liverpool   24   9.00   644.972826
#                Naby Keïta         Liverpool   23  60.00   847.457145
#                   Fabinho         Liverpool   24  45.00   781.812503
#           Xherdan Shaqiri         Liverpool   26  14.70   667.365772
#          Antonio Valencia Manchester United   32  18.80   669.429348
#            Chris Smalling Manchester United   28   8.00   569.089674
#                Phil Jones Manchester United   26  19.30   630.502717
#              Ashley Young Manchester United   33  18.00   715.828804
#                 Juan Mata Manchester United   30  44.73   589.184094
#         Marouane Fellaini Manchester United   30  32.40   740.509714
#                 Luke Shaw Manchester United   23  37.50   636.413043
#             Ander Herrera Manchester United   28  36.00   805.878396
#           Anthony Martial Manchester United   22  60.00   822.264501
#            Matteo Darmian Manchester United   28  18.00   755.163043
#                Paul Pogba Manchester United   25 105.00   840.942678
#               Eric Bailly Manchester United   24  38.00   811.209239
#             Romelu Lukaku Manchester United   25  84.70   732.674177
#           Victor Lindelöf Manchester United   24  35.00   480.978261
#            Alexis Sánchez Manchester United   29  34.00   682.168075
#                      Fred Manchester United   25  59.00   888.172433
#               Diogo Dalot Manchester United   19  22.00   579.483696
#                David Luiz           Chelsea   31  25.00   529.823370
#               Eden Hazard           Chelsea   27  35.00   864.535145
#         César Azpilicueta           Chelsea   28   8.80   730.570652
#                   Willian           Chelsea   29  35.50   736.115772
#                     Pedro           Chelsea   31  27.00   875.993478
#              N'Golo Kanté           Chelsea   27  35.80   796.061893
#                David Luiz           Chelsea   31  35.00   529.823370
#             Marcos Alonso           Chelsea   27  23.00   678.600543
#             Álvaro Morata           Chelsea   25  66.00   575.573266
#           Antonio Rüdiger           Chelsea   25  35.00   429.823370
#            Olivier Giroud           Chelsea   31  17.00   836.772681
#              Ross Barkley           Chelsea   24  16.80   965.834762
#                  Jorginho           Chelsea   26  57.00   840.567763
#           Gonzalo Higuaín           Chelsea   30   7.80   422.668734
#              Aaron Ramsey           Arsenal   27   6.40   924.336528
#         Laurent Koscielny           Arsenal   32  12.50   760.597826
#             Nacho Monreal           Arsenal   32  10.00   778.940217
#                Mesut Özil           Arsenal   29  47.00   821.576412
#              Granit Xhaka           Arsenal   25  45.00   845.265571
#          Shkodran Mustafi           Arsenal   26  41.00   672.894022
#               Rob Holding           Arsenal   22   3.00   667.730978
# Pierre-Emerick Aubameyang           Arsenal   29  63.75   772.162382
#       Alexandre Lacazette           Arsenal   27  53.00   774.595268
#        Henrikh Mkhitaryan           Arsenal   29  34.00   751.331795
#            Lucas Torreira           Arsenal   22  28.65   713.046855
# Sokratis Papastathopoulos           Arsenal   30  16.00   687.839674
#          Mattéo Guendouzi           Arsenal   19   8.00   853.581372
#                Danny Rose Tottenham Hotspur   28   1.00   669.089674
#             Mousa Dembélé Tottenham Hotspur   31  19.00   607.092099
#            Jan Vertonghen Tottenham Hotspur   31  12.50   756.453804
#         Christian Eriksen Tottenham Hotspur   26  14.15   829.965326
#                Ben Davies Tottenham Hotspur   25  12.65   732.472826
#                 Dele Alli Tottenham Hotspur   22   6.63   799.039401
#                 Eric Dier Tottenham Hotspur   24   5.00   643.359436
#         Toby Alderweireld Tottenham Hotspur   29  16.00   675.135870
#           Kieran Trippier Tottenham Hotspur   27   4.90   751.086957
#            Moussa Sissoko Tottenham Hotspur   28  35.00   665.295699
#            Victor Wanyama Tottenham Hotspur   27  14.40   711.328762
#          Davinson Sánchez Tottenham Hotspur   22  42.00   629.008152
#               Lucas Moura Tottenham Hotspur   25  28.40   689.222795
#              Serge Aurier Tottenham Hotspur   25  25.00   891.711957
#         Fernando Llorente Tottenham Hotspur   33  15.10   834.009718
#                Juan Foyth Tottenham Hotspur   20  10.50   640.489130
#           Vincent Kompany   Manchester City   32   8.50   539.402174
#               David Silva   Manchester City   32  28.75   902.124565
#             Sergio Agüero   Manchester City   30  40.00   829.651796
#               Fernandinho   Manchester City   33  40.00   877.377928
#           Kevin De Bruyne   Manchester City   27  76.00   903.645135
#           Raheem Sterling   Manchester City   23  63.70   946.620326
#          Nicolás Otamendi   Manchester City   30  44.50   615.421196
#              Fabian Delph   Manchester City   28  11.50   595.380435
#               John Stones   Manchester City   24  55.60   576.019022
#                Leroy Sané   Manchester City   22  52.00   873.592801
#             Gabriel Jesus   Manchester City   21  32.00   831.856224
#            İlkay Gündoğan   Manchester City   27  27.00   896.263701
#       Oleksandr Zinchenko   Manchester City   21   2.25   658.967391
#           Aymeric Laporte   Manchester City   24  65.00   486.480978
#            Benjamin Mendy   Manchester City   24  57.50   546.875000
#               Kyle Walker   Manchester City   28  52.70   512.364130
#            Bernardo Silva   Manchester City   23  50.00   815.221027
#                    Danilo   Manchester City   27  30.00   528.872283
#              Riyad Mahrez   Manchester City   27  67.80   885.723025

# %%
import pandas as pd

# Einlesen der CSV-Datei
transfers_df = pd.read_csv('../filtered_arrivals_with_additional_data.csv')

# Manuelle Zuordnung der Positionen für die Spieler
positions = {
    "Jordan Henderson": "MF",
    "Daniel Sturridge": "FW",
    "Adam Lallana": "MF",
    "Dejan Lovren": "DF",
    "Roberto Firmino": "FW",
    "Joe Gomez": "DF",
    "Sadio Mané": "FW",
    "Georginio Wijnaldum": "MF",
    "Virgil van Dijk": "DF",
    "Mohamed Salah": "FW",
    "Andrew Robertson": "DF",
    "Naby Keïta": "MF",
    "Fabinho": "MF",
    "Xherdan Shaqiri": "FW",
    "Antonio Valencia": "DF",
    "Chris Smalling": "DF",
    "Phil Jones": "DF",
    "Ashley Young": "DF",
    "Juan Mata": "MF",
    "Marouane Fellaini": "MF",
    "Luke Shaw": "DF",
    "Ander Herrera": "MF",
    "Anthony Martial": "FW",
    "Matteo Darmian": "DF",
    "Paul Pogba": "MF",
    "Eric Bailly": "DF",
    "Romelu Lukaku": "FW",
    "Victor Lindelöf": "DF",
    "Alexis Sánchez": "FW",
    "Fred": "MF",
    "Diogo Dalot": "DF",
    "David Luiz": "DF",
    "Eden Hazard": "FW",
    "César Azpilicueta": "DF",
    "Willian": "FW",
    "Pedro": "FW",
    "N'Golo Kanté": "MF",
    "Marcos Alonso": "DF",
    "Álvaro Morata": "FW",
    "Antonio Rüdiger": "DF",
    "Olivier Giroud": "FW",
    "Ross Barkley": "MF",
    "Jorginho": "MF",
    "Gonzalo Higuaín": "FW",
    "Aaron Ramsey": "MF",
    "Laurent Koscielny": "DF",
    "Nacho Monreal": "DF",
    "Mesut Özil": "MF",
    "Granit Xhaka": "MF",
    "Shkodran Mustafi": "DF",
    "Rob Holding": "DF",
    "Pierre-Emerick Aubameyang": "FW",
    "Alexandre Lacazette": "FW",
    "Henrikh Mkhitaryan": "MF",
    "Lucas Torreira": "MF",
    "Sokratis Papastathopoulos": "DF",
    "Mattéo Guendouzi": "MF",
    "Danny Rose": "DF",
    "Mousa Dembélé": "MF",
    "Jan Vertonghen": "DF",
    "Christian Eriksen": "MF",
    "Ben Davies": "DF",
    "Dele Alli": "MF",
    "Eric Dier": "DF",
    "Toby Alderweireld": "DF",
    "Kieran Trippier": "DF",
    "Moussa Sissoko": "MF",
    "Victor Wanyama": "MF",
    "Davinson Sánchez": "DF",
    "Lucas Moura": "FW",
    "Serge Aurier": "DF",
    "Fernando Llorente": "FW",
    "Juan Foyth": "DF",
    "Vincent Kompany": "DF",
    "David Silva": "MF",
    "Sergio Agüero": "FW",
    "Fernandinho": "MF",
    "Kevin De Bruyne": "MF",
    "Raheem Sterling": "FW",
    "Nicolás Otamendi": "DF",
    "Fabian Delph": "MF",
    "John Stones": "DF",
    "Leroy Sané": "FW",
    "Gabriel Jesus": "FW",
    "İlkay Gündoğan": "MF",
    "Oleksandr Zinchenko": "MF",
    "Aymeric Laporte": "DF",
    "Benjamin Mendy": "DF",
    "Kyle Walker": "DF",
    "Bernardo Silva": "MF",
    "Danilo": "DF",
    "Riyad Mahrez": "FW"
}

# Positionen zuordnen
transfers_df['Position'] = transfers_df['Player'].map(positions)

# Aktualisierte CSV-Datei speichern
transfers_df.to_csv('../filtered_arrivals_with_additional_data.csv', index=False)

# Ausgabe der aktualisierten Daten zur Überprüfung
print(transfers_df.to_string(index=False))
# Out:
#                    Player              Club  Age    Fee  Total Score Position
#          Jordan Henderson         Liverpool   28  18.00   859.117708       MF
#          Daniel Sturridge         Liverpool   28  15.00   681.870955       FW
#              Adam Lallana         Liverpool   30  31.00   678.129578       MF
#              Dejan Lovren         Liverpool   29  25.30   500.475543       DF
#           Roberto Firmino         Liverpool   26  41.00   754.856534       FW
#                 Joe Gomez         Liverpool   21   4.90   665.217391       DF
#                Sadio Mané         Liverpool   26  41.20   803.639342       FW
#       Georginio Wijnaldum         Liverpool   27  27.50   697.077425       MF
#           Virgil van Dijk         Liverpool   27  84.65   578.192935       DF
#             Mohamed Salah         Liverpool   26  42.00   800.055429       FW
#          Andrew Robertson         Liverpool   24   9.00   644.972826       DF
#                Naby Keïta         Liverpool   23  60.00   847.457145       MF
#                   Fabinho         Liverpool   24  45.00   781.812503       MF
#           Xherdan Shaqiri         Liverpool   26  14.70   667.365772       FW
#          Antonio Valencia Manchester United   32  18.80   669.429348       DF
#            Chris Smalling Manchester United   28   8.00   569.089674       DF
#                Phil Jones Manchester United   26  19.30   630.502717       DF
#              Ashley Young Manchester United   33  18.00   715.828804       DF
#                 Juan Mata Manchester United   30  44.73   589.184094       MF
#         Marouane Fellaini Manchester United   30  32.40   740.509714       MF
#                 Luke Shaw Manchester United   23  37.50   636.413043       DF
#             Ander Herrera Manchester United   28  36.00   805.878396       MF
#           Anthony Martial Manchester United   22  60.00   822.264501       FW
#            Matteo Darmian Manchester United   28  18.00   755.163043       DF
#                Paul Pogba Manchester United   25 105.00   840.942678       MF
#               Eric Bailly Manchester United   24  38.00   811.209239       DF
#             Romelu Lukaku Manchester United   25  84.70   732.674177       FW
#           Victor Lindelöf Manchester United   24  35.00   480.978261       DF
#            Alexis Sánchez Manchester United   29  34.00   682.168075       FW
#                      Fred Manchester United   25  59.00   888.172433       MF
#               Diogo Dalot Manchester United   19  22.00   579.483696       DF
#                David Luiz           Chelsea   31  25.00   529.823370       DF
#               Eden Hazard           Chelsea   27  35.00   864.535145       FW
#         César Azpilicueta           Chelsea   28   8.80   730.570652       DF
#                   Willian           Chelsea   29  35.50   736.115772       FW
#                     Pedro           Chelsea   31  27.00   875.993478       FW
#              N'Golo Kanté           Chelsea   27  35.80   796.061893       MF
#                David Luiz           Chelsea   31  35.00   529.823370       DF
#             Marcos Alonso           Chelsea   27  23.00   678.600543       DF
#             Álvaro Morata           Chelsea   25  66.00   575.573266       FW
#           Antonio Rüdiger           Chelsea   25  35.00   429.823370       DF
#            Olivier Giroud           Chelsea   31  17.00   836.772681       FW
#              Ross Barkley           Chelsea   24  16.80   965.834762       MF
#                  Jorginho           Chelsea   26  57.00   840.567763       MF
#           Gonzalo Higuaín           Chelsea   30   7.80   422.668734       FW
#              Aaron Ramsey           Arsenal   27   6.40   924.336528       MF
#         Laurent Koscielny           Arsenal   32  12.50   760.597826       DF
#             Nacho Monreal           Arsenal   32  10.00   778.940217       DF
#                Mesut Özil           Arsenal   29  47.00   821.576412       MF
#              Granit Xhaka           Arsenal   25  45.00   845.265571       MF
#          Shkodran Mustafi           Arsenal   26  41.00   672.894022       DF
#               Rob Holding           Arsenal   22   3.00   667.730978       DF
# Pierre-Emerick Aubameyang           Arsenal   29  63.75   772.162382       FW
#       Alexandre Lacazette           Arsenal   27  53.00   774.595268       FW
#        Henrikh Mkhitaryan           Arsenal   29  34.00   751.331795       MF
#            Lucas Torreira           Arsenal   22  28.65   713.046855       MF
# Sokratis Papastathopoulos           Arsenal   30  16.00   687.839674       DF
#          Mattéo Guendouzi           Arsenal   19   8.00   853.581372       MF
#                Danny Rose Tottenham Hotspur   28   1.00   669.089674       DF
#             Mousa Dembélé Tottenham Hotspur   31  19.00   607.092099       MF
#            Jan Vertonghen Tottenham Hotspur   31  12.50   756.453804       DF
#         Christian Eriksen Tottenham Hotspur   26  14.15   829.965326       MF
#                Ben Davies Tottenham Hotspur   25  12.65   732.472826       DF
#                 Dele Alli Tottenham Hotspur   22   6.63   799.039401       MF
#                 Eric Dier Tottenham Hotspur   24   5.00   643.359436       DF
#         Toby Alderweireld Tottenham Hotspur   29  16.00   675.135870       DF
#           Kieran Trippier Tottenham Hotspur   27   4.90   751.086957       DF
#            Moussa Sissoko Tottenham Hotspur   28  35.00   665.295699       MF
#            Victor Wanyama Tottenham Hotspur   27  14.40   711.328762       MF
#          Davinson Sánchez Tottenham Hotspur   22  42.00   629.008152       DF
#               Lucas Moura Tottenham Hotspur   25  28.40   689.222795       FW
#              Serge Aurier Tottenham Hotspur   25  25.00   891.711957       DF
#         Fernando Llorente Tottenham Hotspur   33  15.10   834.009718       FW
#                Juan Foyth Tottenham Hotspur   20  10.50   640.489130       DF
#           Vincent Kompany   Manchester City   32   8.50   539.402174       DF
#               David Silva   Manchester City   32  28.75   902.124565       MF
#             Sergio Agüero   Manchester City   30  40.00   829.651796       FW
#               Fernandinho   Manchester City   33  40.00   877.377928       MF
#           Kevin De Bruyne   Manchester City   27  76.00   903.645135       MF
#           Raheem Sterling   Manchester City   23  63.70   946.620326       FW
#          Nicolás Otamendi   Manchester City   30  44.50   615.421196       DF
#              Fabian Delph   Manchester City   28  11.50   595.380435       MF
#               John Stones   Manchester City   24  55.60   576.019022       DF
#                Leroy Sané   Manchester City   22  52.00   873.592801       FW
#             Gabriel Jesus   Manchester City   21  32.00   831.856224       FW
#            İlkay Gündoğan   Manchester City   27  27.00   896.263701       MF
#       Oleksandr Zinchenko   Manchester City   21   2.25   658.967391       MF
#           Aymeric Laporte   Manchester City   24  65.00   486.480978       DF
#            Benjamin Mendy   Manchester City   24  57.50   546.875000       DF
#               Kyle Walker   Manchester City   28  52.70   512.364130       DF
#            Bernardo Silva   Manchester City   23  50.00   815.221027       MF
#                    Danilo   Manchester City   27  30.00   528.872283       DF
#              Riyad Mahrez   Manchester City   27  67.80   885.723025       FW
