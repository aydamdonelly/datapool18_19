# %% [markdown]
# # Aggregating all player data for in-depth analyses and comparisons

# %%
# libraries
import pandas as pd
import numpy as np
import time
import re

# %% [markdown]
# #### Getting the standard stats for all players playing for clubs from the Top5 leagues in 2018/19

# %%
# creating list of urls for each top5 league club from the 18-19 season
url_list = open('urls/top5_league_clubs.txt').read().splitlines()
#read the first url
table = pd.read_html(url_list[0])

# %%
from urllib.parse import urlparse
# Initialize an empty list to store dataframes
dfs = []

# Set the delay between requests (in seconds)
delay_between_requests = 1  # Adjust this value as needed

for url in url_list:
    try:
        # Read HTML tables from the URL
        tables = pd.read_html(url, attrs={"id": "stats_shooting_combined"})

        df = tables[0]
        print(tables[0].head())
        # Drop the last two rows
        df = df.iloc[:-2]
        
        # Extract club name from the URL using regex
        club_name_match = re.search(r"all_comps/(.*?)-Stats-All-Competitions", url)
        if club_name_match:
            club_name = club_name_match.group(1).replace('-', ' ')
        else:
            raise ValueError("Club name not found in URL pattern.")
        
        # Create a new column with the club name
        df['Club'] = club_name
        
        # Append the dataframe to the list
        dfs.append(df)
        
        # Introduce a delay before making the next request
        time.sleep(delay_between_requests)
    except Exception as e:
        print(f"Error reading data from {url}: {str(e)}")

# Concatenate all dataframes into one
total_df = pd.concat(dfs, ignore_index=True)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0            Ederson             br BRA                 GK                 24
# 1    Aymeric Laporte             es ESP                 DF                 24
# 2        Kyle Walker            eng ENG                 DF                 28
# 3    Raheem Sterling            eng ENG                 FW                 23
# 4     Bernardo Silva             pt POR              MF,FW                 23
#
#   Unnamed: 4_level_0 Standard                       ...                      \
#                  90s      Gls   Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               55.3        0    0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               48.3        5   36   9  25.0  0.74  ...  15.0  0.0  0     0
# 2               48.1        2   30   6  20.0  0.62  ...  27.8  3.0  0     0
# 3               45.8       25  113  55  48.7  2.47  ...  14.2  1.0  0     0
# 4               44.8       13   85  35  41.2  1.90  ...  15.9  0.0  0     0
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0   0.0     NaN  0.0     0.0             Matches
# 1      3.5   3.5    0.11  1.5     1.5             Matches
# 2      0.9   0.9    0.04  0.1     0.1             Matches
# 3     16.7  16.7    0.17  5.3     5.3             Matches
# 4      9.0   9.0    0.12  2.0     2.0             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0            Alisson             br BRA                 GK                 25
# 1    Virgil van Dijk             nl NED                 DF                 27
# 2      Mohamed Salah             eg EGY                 FW                 26
# 3         Sadio Mané             sn SEN                 FW                 26
# 4   Andrew Robertson            sct SCO                 DF                 24
#
#   Unnamed: 4_level_0 Standard                       ...                      \
#                  90s      Gls   Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               51.0        0    0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               49.6        6   41  13  31.7  0.83  ...  12.8  1.0  0     0
# 2               48.1       27  185  73  39.5  3.84  ...  17.1  4.0  5     5
# 3               47.7       26  113  51  45.1  2.37  ...  12.9  0.0  0     1
# 4               46.9        0   22   8  36.4  0.47  ...  18.4  0.0  0     0
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0   0.0     NaN  0.0     0.0             Matches
# 1      5.2   5.2    0.13  0.8     0.8             Matches
# 2     27.3  23.4    0.13 -0.3    -1.4             Matches
# 3     23.2  22.3    0.20  2.8     3.7             Matches
# 4      1.1   1.1    0.05 -1.1    -1.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0  Kepa Arrizabalaga             es ESP                 GK                 23
# 1  César Azpilicueta             es ESP                 DF                 28
# 2           Jorginho             it ITA                 MF                 26
# 3         David Luiz             br BRA                 DF                 31
# 4       N'Golo Kanté             fr FRA                 MF                 27
#
#   Unnamed: 4_level_0 Standard                      ...                       \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist    FK PK PKatt
# 0               55.0        0   0   0   NaN  0.00  ...   NaN   0.0  0     0
# 1               54.4        1  23   8  34.8  0.42  ...  16.1   0.0  0     0
# 2               49.0        2  22   7  31.8  0.45  ...  26.4   0.0  1     1
# 3               48.6        3  44  11  25.0  0.91  ...  18.6  11.0  0     0
# 4               46.8        5  38   9  23.7  0.81  ...  18.5   0.0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0  0.0     NaN  0.0     0.0             Matches
# 1      1.4  1.4    0.07 -0.4    -0.4             Matches
# 2      1.4  0.6    0.03  0.6     0.4             Matches
# 3      3.2  3.2    0.08 -0.2    -0.2             Matches
# 4      3.0  3.0    0.10  1.0     1.0             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0  Toby Alderweireld             be BEL                 DF                 29
# 1  Christian Eriksen             dk DEN              MF,FW                 26
# 2        Hugo Lloris             fr FRA                 GK                 31
# 3     Moussa Sissoko             fr FRA                 MF                 28
# 4         Harry Kane            eng ENG                 FW                 25
#
#   Unnamed: 4_level_0 Standard                       ...                       \
#                  90s      Gls   Sh SoT  SoT% Sh/90  ...  Dist    FK PK PKatt
# 0               49.1        0   29   8  27.6  0.59  ...  12.6   0.0  0     0
# 1               46.2       10  119  43  36.1  2.58  ...  23.5  17.0  0     0
# 2               43.9        0    0   0   NaN  0.00  ...   NaN   0.0  0     0
# 3               37.7        0   21   4  19.0  0.56  ...  25.1   0.0  0     0
# 4               37.1       24  134  61  45.5  3.61  ...  16.9   7.0  5     5
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      2.0   2.0    0.07 -2.0    -2.0             Matches
# 1      7.8   7.8    0.07  2.2     2.2             Matches
# 2      0.0   0.0     NaN  0.0     0.0             Matches
# 3      1.1   1.1    0.06 -1.1    -1.1             Matches
# 4     17.6  14.5    0.11  4.4     3.5             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#           Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                       Player             Nation                Pos
# 0  Pierre-Emerick Aubameyang             ga GAB                 FW
# 1               Granit Xhaka             ch SUI              MF,DF
# 2  Sokratis Papastathopoulos             gr GRE                 DF
# 3           Shkodran Mustafi             de GER                 DF
# 4        Alexandre Lacazette             fr FRA                 FW
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                       ...  \
#                  Age                90s      Gls   Sh SoT  SoT% Sh/90  ...
# 0                 29               42.8       31  140  57  40.7  3.27  ...
# 1                 25               38.2        4   37  12  32.4  0.97  ...
# 2                 30               37.5        3   19   4  21.1  0.51  ...
# 3                 26               37.0        3   29  10  34.5  0.78  ...
# 4                 27               37.0       19  109  40  36.7  2.95  ...
#
#                       Expected                            Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0  14.6  2.0  4     5     29.9  25.8    0.19  0.1     0.2             Matches
# 1  27.1  8.0  0     0      2.2   2.2    0.06  1.8     1.8             Matches
# 2  10.5  0.0  0     0      2.4   2.4    0.13  0.6     0.6             Matches
# 3  10.6  0.0  0     0      2.0   2.0    0.08  1.0     1.0             Matches
# 4  14.7  3.0  0     0     14.8  14.8    0.15  3.2     3.2             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0       David de Gea             es ESP                 GK                 27
# 1         Paul Pogba             fr FRA                 MF                 25
# 2          Luke Shaw            eng ENG                 DF                 23
# 3       Ashley Young            eng ENG                 DF                 33
# 4    Victor Lindelöf             se SWE                 DF                 24
#
#   Unnamed: 4_level_0 Standard                       ...                      \
#                  90s      Gls   Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               47.0        0    0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               44.5       16  112  48  42.9  2.52  ...  23.3  7.0  8    11
# 2               39.8        1   25   8  32.0  0.63  ...  19.7  0.0  0     0
# 3               39.3        2   14   3  21.4  0.36  ...  22.2  2.0  0     0
# 4               38.9        1   10   2  20.0  0.26  ...  11.2  0.0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0  0.0     NaN  0.0     0.0             Matches
# 1     16.8  8.1    0.07 -1.8    -1.1             Matches
# 2      1.6  1.5    0.06 -0.6    -0.5             Matches
# 3      0.5  0.5    0.04  1.5     1.5             Matches
# 4      0.8  0.8    0.08  0.2     0.2             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Conor Coady            eng ENG                 DF                 25
# 1       Matt Doherty             ie IRL              DF,MF                 26
# 2         Willy Boly             ci CIV                 DF                 27
# 3       Raúl Jiménez             mx MEX                 FW                 27
# 4       Ryan Bennett            eng ENG                 DF                 28
#
#   Unnamed: 4_level_0 Standard                       ...                      \
#                  90s      Gls   Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               46.7        0    0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               41.3        8   53  21  39.6  1.28  ...  12.9  0.0  0     0
# 2               40.5        4   29   6  20.7  0.72  ...  11.0  0.0  0     0
# 3               39.3       17  125  40  32.0  3.18  ...  14.6  0.0  2     2
# 4               38.9        1   16   4  25.0  0.41  ...  12.5  0.0  0     0
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0   0.0     NaN  0.0     0.0             Matches
# 1      4.4   4.4    0.10 -0.4    -0.4             Matches
# 2      3.6   3.6    0.15  0.4     0.4             Matches
# 3     15.1  13.6    0.13 -2.1    -2.6             Matches
# 4      1.3   1.3    0.08 -0.3    -0.3             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0     Jordan Pickford            eng ENG                 GK
# 1    Gylfi Sigurðsson             is ISL                 MF
# 2       Michael Keane            eng ENG                 DF
# 3         Lucas Digne             fr FRA                 DF
# 4  Idrissa Gana Gueye             sn SEN                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 24               40.0        0   0   0   NaN  0.00  ...
# 1                 28               37.2       14  89  33  37.1  2.39  ...
# 2                 25               35.3        1  31   9  29.0  0.88  ...
# 3                 25               34.9        4  35  10  28.6  1.00  ...
# 4                 28               33.4        0  20   4  20.0  0.60  ...
#
#                        Expected                           Unnamed: 22_level_0
#    Dist    FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0   NaN   0.0  0     0      0.0  0.0     NaN  0.0     0.0             Matches
# 1  20.3   7.0  2     5     10.7  6.7    0.08  2.3     4.3             Matches
# 2  10.6   0.0  0     0      2.3  2.3    0.08 -1.3    -1.3             Matches
# 3  25.0  11.0  0     0      1.3  1.3    0.04  2.7     2.7             Matches
# 4  24.3   0.0  0     0      0.6  0.6    0.03 -0.6    -0.6             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0      Wilfred Ndidi             ng NGA                 MF                 21
# 1  Kasper Schmeichel             dk DEN                 GK                 31
# 2    Ricardo Pereira             pt POR              DF,FW                 24
# 3       Ben Chilwell            eng ENG                 DF                 21
# 4     James Maddison            eng ENG              MF,FW                 21
#
#   Unnamed: 4_level_0 Standard                      ...                       \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist    FK PK PKatt
# 0               39.3        2  57   9  15.8  1.45  ...  20.9   0.0  0     0
# 1               38.0        0   1   0   0.0  0.03  ...   9.6   0.0  0     0
# 2               36.5        2  26   9  34.6  0.71  ...  20.2   0.0  0     0
# 3               36.0        0  22  10  45.5  0.61  ...  21.4   0.0  0     0
# 4               32.7        7  85  27  31.8  2.60  ...  22.4  15.0  1     2
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      3.7  3.7    0.07 -1.7    -1.7             Matches
# 1      0.1  0.1    0.06 -0.1    -0.1             Matches
# 2      1.2  1.2    0.05  0.8     0.8             Matches
# 3      1.1  1.1    0.05 -1.1    -1.1             Matches
# 4      7.4  5.9    0.07 -0.4     0.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0   Łukasz Fabiański             pl POL                 GK                 33
# 1          Issa Diop             fr FRA                 DF                 21
# 2        Declan Rice            eng ENG                 MF                 19
# 3    Felipe Anderson             br BRA              MF,FW                 25
# 4   Robert Snodgrass            sct SCO                 MF                 30
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               38.0        0   0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               38.0        2  17   6  35.3  0.45  ...  10.1  0.0  0     0
# 2               37.3        2  23   5  21.7  0.62  ...  18.3  0.0  0     0
# 3               35.4       10  63  26  41.3  1.78  ...  18.7  5.0  0     0
# 4               28.5        4  36  10  27.8  1.26  ...  19.9  4.0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0  0.0     NaN  0.0     0.0             Matches
# 1      1.2  1.2    0.10 -0.2    -0.2             Matches
# 2      1.2  1.2    0.05  0.8     0.8             Matches
# 3      5.5  5.5    0.09  3.5     3.5             Matches
# 4      2.3  2.3    0.08 -0.3    -0.3             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Craig Cathcart            nir NIR                 DF
# 1          Ben Foster            eng ENG                 GK
# 2  Abdoulaye Doucouré             ml MLI                 MF
# 3      Étienne Capoue             fr FRA                 MF
# 4     Roberto Pereyra             ar ARG                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 29               40.1        3  14   5  35.7  0.35  ...
# 1                 35               38.0        0   1   0   0.0  0.03  ...
# 2                 25               37.6        5  58  16  27.6  1.54  ...
# 3                 30               37.6        4  24   7  29.2  0.64  ...
# 4                 27               34.3        6  60  23  38.3  1.75  ...
#
#                       Expected                           Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0  10.2  0.0  0     0      1.5  1.5    0.12  1.5     1.5             Matches
# 1  28.3  0.0  0     0      0.0  0.0    0.02  0.0     0.0             Matches
# 2  17.6  0.0  0     0      6.2  6.2    0.13 -1.2    -1.2             Matches
# 3  26.7  5.0  0     0      1.4  1.4    0.08 -0.4    -0.4             Matches
# 4  17.5  6.0  0     0      5.4  5.4    0.09  0.6     0.6             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0     Luka Milivojević             rs SRB                 MF
# 1      Andros Townsend            eng ENG              FW,MF
# 2    Aaron Wan-Bissaka            eng ENG                 DF
# 3  Patrick van Aanholt             nl NED                 DF
# 4        Wilfried Zaha             ci CIV                 FW
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 27               40.4       12  51  14  27.5  1.26  ...
# 1                 27               39.5        9  81  28  34.6  2.05  ...
# 2                 20               38.6        0  10   0   0.0  0.26  ...
# 3                 27               38.4        4  52  14  26.9  1.36  ...
# 4                 25               35.7       10  80  29  36.3  2.24  ...
#
#                         Expected                           Unnamed: 22_level_0
#    Dist    FK  PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0  30.0  16.0  10    11     10.9  2.2    0.05  1.1    -0.2             Matches
# 1  22.1   0.0   1     1      4.6  4.6    0.07  1.4     1.4             Matches
# 2  17.9   0.0   0     0      0.5  0.5    0.05 -0.5    -0.5             Matches
# 3  20.7   0.0   0     0      2.6  2.6    0.06  0.4     0.4             Matches
# 4  16.7   0.0   0     0      5.7  5.7    0.08  4.3     4.3             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0    Martin Dúbravka             sk SVK                 GK                 29
# 1       Matt Ritchie            sct SCO              DF,MF                 28
# 2        Ayoze Pérez             es ESP              MF,FW                 25
# 3   Jamaal Lascelles            eng ENG                 DF                 24
# 4     Salomón Rondón             ve VEN                 FW                 28
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               38.0        0   0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               35.5        3  46  12  26.1  1.29  ...  19.2  0.0  2     3
# 2               33.3       13  58  28  48.3  1.74  ...  13.9  0.0  0     0
# 3               31.6        0  11   1   9.1  0.35  ...  11.2  0.0  0     0
# 4               29.0       12  90  28  31.1  3.10  ...  15.8  9.0  0     0
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0   0.0     NaN  0.0     0.0             Matches
# 1      5.1   3.6    0.09 -3.1    -2.6             Matches
# 2      7.5   7.5    0.14  4.5     4.5             Matches
# 3      0.6   0.6    0.06 -0.6    -0.6             Matches
# 4     10.4  10.4    0.12  0.6     0.6             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0         Nathan Aké             nl NED                 DF                 23
# 1        Ryan Fraser            sct SCO              MF,FW                 24
# 2         Steve Cook            eng ENG                 DF                 27
# 3        Joshua King             no NOR              FW,MF                 26
# 4    Jefferson Lerma             co COL                 MF                 23
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               38.9        4  25   8  32.0  0.64  ...   9.4  0.0  0     0
# 1               37.5        8  58  27  46.6  1.55  ...  19.9  4.0  0     0
# 2               34.2        2  26  12  46.2  0.76  ...  16.5  0.0  0     0
# 3               33.6       12  67  18  26.9  1.99  ...  16.3  0.0  5     6
# 4               29.8        2  34   9  26.5  1.14  ...  25.8  0.0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      3.4  3.4    0.13  0.6     0.6             Matches
# 1      4.7  4.7    0.09  2.3     2.3             Matches
# 2      1.3  1.3    0.06 -0.3    -0.3             Matches
# 3     13.5  8.7    0.13 -1.5    -1.7             Matches
# 4      1.3  1.3    0.04  0.7     0.7             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0            Ben Mee            eng ENG                 DF                 28
# 1     Charlie Taylor            eng ENG                 DF                 24
# 2          Jack Cork            eng ENG                 MF                 29
# 3    James Tarkowski            eng ENG                 DF                 25
# 4    Ashley Westwood            eng ENG                 MF                 28
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               39.0        0  22   5  22.7  0.56  ...   9.8  0.0  0     0
# 1               38.0        0   6   0   0.0  0.16  ...  28.0  0.0  0     0
# 2               37.4        1  17   2  11.8  0.45  ...  16.6  0.0  0     0
# 3               36.3        3  23   9  39.1  0.63  ...   7.2  0.0  0     0
# 4               32.5        2  23   7  30.4  0.71  ...  22.2  1.0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      1.6  1.6    0.08 -1.6    -1.6             Matches
# 1      0.2  0.2    0.03 -0.2    -0.2             Matches
# 2      1.4  1.4    0.08 -0.4    -0.4             Matches
# 3      3.3  3.3    0.16 -0.3    -0.3             Matches
# 4      1.9  1.9    0.09  0.1     0.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Nathan Redmond            eng ENG              MF,FW
# 1     Pierre Højbjerg             dk DEN                 MF
# 2        Jan Bednarek             pl POL                 DF
# 3  Jannik Vestergaard             dk DEN                 DF
# 4         Oriol Romeu             es ESP                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 24               40.9        9  85  29  34.1  2.08  ...
# 1                 22               33.3        4  56  20  35.7  1.68  ...
# 2                 22               26.2        0   5   1  20.0  0.19  ...
# 3                 25               26.2        0  14   1   7.1  0.53  ...
# 4                 26               25.8        1  10   4  40.0  0.39  ...
#
#                       Expected                           Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0  19.9  3.0  0     0      7.6  7.6    0.11 -1.6    -1.6             Matches
# 1  24.2  2.0  0     0      2.6  2.6    0.05  1.4     1.4             Matches
# 2   7.5  0.0  0     0      0.8  0.8    0.16 -0.8    -0.8             Matches
# 3  15.8  2.0  0     0      0.7  0.7    0.05 -0.7    -0.7             Matches
# 4  21.7  0.0  0     0      0.9  0.9    0.10  0.1     0.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Shane Duffy             ie IRL                 DF                 26
# 1         Lewis Dunk            eng ENG                 DF                 26
# 2        Mathew Ryan             au AUS                 GK                 26
# 3      Dale Stephens            eng ENG                 MF                 29
# 4       Davy Pröpper             nl NED                 MF                 26
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               39.6        5  43  15  34.9  1.08  ...  10.6  0.0  0     0
# 1               37.3        2  20   4  20.0  0.54  ...  14.1  2.0  0     0
# 2               36.3        0   0   0   NaN  0.00  ...   NaN  0.0  0     0
# 3               32.6        1  16   3  18.8  0.49  ...  27.4  0.0  0     0
# 4               31.6        1  19   2  10.5  0.60  ...  15.9  0.0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      3.1  3.1    0.08  1.9     1.9             Matches
# 1      1.8  1.8    0.09  0.2     0.2             Matches
# 2      0.0  0.0     NaN  0.0     0.0             Matches
# 3      0.3  0.3    0.03  0.7     0.7             Matches
# 4      0.9  0.9    0.06  0.1     0.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0  Bruno Ecuele Manga             ga GAB                 DF
# 1      Neil Etheridge             ph PHI                 GK
# 2       Sean Morrison            eng ENG                 DF
# 3         Joe Bennett            eng ENG                 DF
# 4     Víctor Camarasa             es ESP                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 30               39.5        1  11   4  36.4  0.28  ...
# 1                 28               38.0        0   0   0   NaN  0.00  ...
# 2                 27               34.8        1  35   9  25.7  1.01  ...
# 3                 28               30.3        0  12   4  33.3  0.40  ...
# 4                 24               29.3        5  40  11  27.5  1.36  ...
#
#                       Expected                           Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0  13.4  0.0  0     0      1.1  1.1    0.11 -1.1    -1.1             Matches
# 1   NaN  0.0  0     0      0.0  0.0     NaN  0.0     0.0             Matches
# 2   9.7  0.0  0     0      5.0  5.0    0.15 -4.0    -4.0             Matches
# 3  23.8  3.0  0     0      0.5  0.5    0.05 -0.5    -0.5             Matches
# 4  23.6  5.0  1     1      4.0  3.2    0.10  1.0     0.8             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0  Aleksandar Mitrović             rs SRB                 FW
# 1          Sergio Rico             es ESP                 GK
# 2           Denis Odoi             gh GHA                 DF
# 3       Calum Chambers            eng ENG              MF,DF
# 4       Ryan Sessegnon            eng ENG              FW,DF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                       ...  \
#                  Age                90s      Gls   Sh SoT  SoT% Sh/90  ...
# 0                 23               37.5       11  133  47  35.3  3.54  ...
# 1                 24               32.0        0    0   0   NaN  0.00  ...
# 2                 30               31.1        1   12   2  16.7  0.39  ...
# 3                 23               30.8        2   35  11  31.4  1.14  ...
# 4                 18               27.8        2   30  11  36.7  1.08  ...
#
#                       Expected                            Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0  15.4  2.0  1     2     14.1  13.3    0.10 -3.1    -3.3             Matches
# 1   NaN  0.0  0     0      0.0   0.0     NaN  0.0     0.0             Matches
# 2  18.2  0.0  0     0      0.6   0.6    0.06 -0.6    -0.6             Matches
# 3  19.4  0.0  0     0      2.3   2.3    0.07 -0.3    -0.3             Matches
# 4  14.9  0.0  0     0      4.0   4.0    0.14 -2.0    -2.0             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#       Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Player             Nation                Pos
# 0  Christopher Schindler             de GER                 DF
# 1            Jonas Lössl             dk DEN                 GK
# 2        Terence Kongolo             nl NED                 DF
# 3          Jonathan Hogg            eng ENG                 MF
# 4             Aaron Mooy             au AUS              MF,FW
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 28               37.2        1  13   3  23.1  0.35  ...
# 1                 29               31.9        0   1   0   0.0  0.03  ...
# 2                 24               30.2        1  14   4  28.6  0.46  ...
# 3                 29               27.3        0   9   1  11.1  0.33  ...
# 4                 27               26.1        3  42  13  31.0  1.61  ...
#
#                     Expected                           Unnamed: 22_level_0
#    Dist FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0  11.5  0  0     0      1.1  1.1    0.09 -0.1    -0.1             Matches
# 1   NaN  0  0     0      0.0  0.0     NaN  0.0     0.0             Matches
# 2  14.9  0  0     0      1.3  1.3    0.09 -0.3    -0.3             Matches
# 3  20.7  0  0     0      0.3  0.3    0.03 -0.3    -0.3             Matches
# 4  23.3  8  1     1      2.8  2.1    0.05  0.2    -0.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Joshua Kimmich             de GER              DF,MF
# 1  Robert Lewandowski             pl POL                 FW
# 2         David Alaba             at AUT                 DF
# 3         Niklas Süle             de GER                 DF
# 4    Thiago Alcántara             es ESP                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                       ...  \
#                  Age                90s      Gls   Sh SoT  SoT% Sh/90  ...
# 0                 23               47.6        2   31   9  29.0  0.65  ...
# 1                 29               46.4       40  188  75  39.9  4.05  ...
# 2                 26               40.4        3   55  19  34.5  1.36  ...
# 3                 22               39.0        2   23   6  26.1  0.59  ...
# 4                 27               38.1        3   37   9  24.3  0.97  ...
#
#                      Expected                            Unnamed: 22_level_0
#    Dist  FK PK PKatt       xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0  18.3   0  0     0      2.9   2.9    0.10 -0.9    -0.9             Matches
# 1  13.3   6  7     8     37.6  32.9    0.20 -7.6    -7.9             Matches
# 2  26.1  19  0     0      3.4   3.4    0.07 -0.4    -0.4             Matches
# 3  16.9   0  0     0      1.6   1.6    0.07  0.4     0.4             Matches
# 4  20.9   1  0     0      2.1   2.1    0.08 -0.1    -0.1             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Axel Witsel             be BEL                 MF                 29
# 1        Roman Bürki             ch SUI                 GK                 27
# 2       Abdou Diallo             sn SEN                 DF                 22
# 3         Marco Reus             de GER              MF,FW                 29
# 4       Jadon Sancho            eng ENG              FW,MF                 18
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               41.2        6  48  15  31.3  1.17  ...  21.0  0.0  0     0
# 1               40.3        0   0   0   NaN  0.00  ...   NaN  0.0  0     0
# 2               36.1        1  14   4  28.6  0.39  ...   7.6  0.0  0     0
# 3               33.8       21  86  40  46.5  2.54  ...  15.9  8.0  4     4
# 4               33.0       13  45  23  51.1  1.36  ...  14.4  0.0  0     0
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      2.9   2.9    0.06  2.1     2.1             Matches
# 1      0.0   0.0     NaN  0.0     0.0             Matches
# 2      2.3   2.3    0.27 -1.3    -1.3             Matches
# 3     17.2  14.9    0.20  0.8     0.1             Matches
# 4      8.2   8.2    0.19  4.8     4.8             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0       Péter Gulácsi             hu HUN                 GK
# 1     Ibrahima Konaté             fr FRA                 DF
# 2      Yussuf Poulsen             dk DEN                 FW
# 3     Marcel Sabitzer             at AUT              MF,FW
# 4  Marcel Halstenberg             de GER                 DF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                      ...  \
#                  Age                90s      Gls  Sh SoT  SoT% Sh/90  ...
# 0                 28               38.8        0   0   0   NaN  0.00  ...
# 1                 19               35.4        2  17   4  23.5  0.48  ...
# 2                 24               34.9       18  85  34  40.0  2.44  ...
# 3                 24               34.5        4  83  23  27.7  2.41  ...
# 4                 26               34.4        4  31  12  38.7  0.90  ...
#
#                     Expected                            Unnamed: 22_level_0
#    Dist FK PK PKatt       xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0   NaN  0  0     0      0.0   0.0     NaN  0.0     0.0             Matches
# 1  11.3  0  0     0      2.2   2.2    0.16 -0.2    -0.2             Matches
# 2  12.7  0  0     0     13.1  12.8    0.18  2.9     3.2             Matches
# 3  20.1  9  0     0      5.4   5.4    0.08 -1.4    -1.4             Matches
# 4  20.5  7  3     3      3.8   2.2    0.09 -0.8    -1.2             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Lukáš Hrádecký             fi FIN                 GK                 28
# 1        Kai Havertz             de GER              MF,FW                 19
# 2       Jonathan Tah             de GER                 DF                 22
# 3      Kevin Volland             de GER              FW,MF                 26
# 4      Julian Brandt             de GER              MF,FW                 22
#
#   Unnamed: 4_level_0 Standard                       ...                    \
#                  90s      Gls   Sh SoT  SoT% Sh/90  ...  Dist FK PK PKatt
# 0               40.0        0    0   0   NaN  0.00  ...   NaN  0  0     0
# 1               38.8       20  108  47  43.5  2.78  ...  17.6  3  3     3
# 2               37.6        3   13   5  38.5  0.35  ...  10.4  0  0     0
# 3               37.5       15   97  45  46.4  2.59  ...  14.5  2  0     0
# 4               37.0       10   83  31  37.3  2.24  ...  19.3  3  0     0
#
#   Expected                            Unnamed: 22_level_0
#         xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.0   0.0     NaN  0.0     0.0             Matches
# 1     13.6  11.2    0.11  6.4     5.8             Matches
# 2      1.2   1.2    0.09  1.8     1.8             Matches
# 3     14.2  14.2    0.15 -0.2    -0.2             Matches
# 4      9.0   9.0    0.12 -1.0    -1.0             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Yann Sommer             ch SUI                 GK                 29
# 1     Thorgan Hazard             be BEL              FW,MF                 25
# 2        Oscar Wendt             se SWE                 DF                 32
# 3        Nico Elvedi             ch SUI                 DF                 21
# 4      Alassane Pléa             fr FRA                 FW                 25
#
#   Unnamed: 4_level_0 Standard                      ...                      \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist   FK PK PKatt
# 0               35.0        0   0   0   NaN  0.00  ...   NaN  0.0  0     0
# 1               33.9       13  80  25  31.3  2.36  ...  21.6  7.0  4     6
# 2               32.0        1   9   5  55.6  0.28  ...  22.9  3.0  0     0
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0  Baptiste Santamaria             fr FRA                 MF
# 1      Ludovic Butelle             fr FRA                 GK
# 2         Flavien Tait             fr FRA              MF,FW
# 3      Vincent Manceau             fr FRA                 DF
# 4        Ismaël Traoré             ci CIV                 DF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                          ...  \
#                  Age                90s      Gls    Sh   SoT  SoT% Sh/90  ...
# 0                 23               38.4        1  24.0   5.0  20.8  0.65  ...
# 1                 35               37.0        0   0.0   0.0   NaN  0.00  ...
# 2                 25               33.9        5  84.0  37.0  44.0  2.53  ...
# 3                 29               33.3        1  16.0   1.0   6.3  0.50  ...
# 4                 31               29.7        3  15.0   6.0  40.0  0.51  ...
#
#                       Expected                           Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0  24.5  1.0  0     0      1.4  1.4    0.06 -0.4    -0.4             Matches
# 1   NaN  0.0  0     0      0.0  0.0     NaN  0.0     0.0             Matches
# 2  21.0  3.0  0     1      7.0  6.1    0.07 -2.0    -1.1             Matches
# 3  24.4  0.0  0     0      0.8  0.8    0.05  0.2     0.2             Matches
# 4  10.5  0.0  0     0      3.6  3.6    0.24 -0.6    -0.6             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0       Jules Koundé             fr FRA                 DF                 19
# 1      Benoît Costil             fr FRA                 GK                 31
# 2             Otávio             br BRA                 MF                 24
# 3       Jimmy Briand             fr FRA                 FW                 32
# 4     Maxime Poundjé             fr FRA                 DF                 25
#
#   Unnamed: 4_level_0 Standard                      ...                    \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist FK PK PKatt
# 0               46.0        1  19   4  21.1  0.44  ...  15.1  0  0     0
# 1               45.0        0   0   0   NaN  0.00  ...   NaN  0  0     0
# 2               38.0        0  23   4  17.4  0.66  ...  27.6  0  0     0
# 3               34.4       10  60  21  35.0  1.83  ...  14.9  0  1     1
# 4               34.3        0  13   2  15.4  0.40  ...  24.6  0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      1.2  1.2    0.07 -0.2    -0.2             Matches
# 1      0.0  0.0     NaN  0.0     0.0             Matches
# 2      0.8  0.8    0.03 -0.8    -0.8             Matches
# 3      8.4  7.6    0.13  0.6     0.4             Matches
# 4      0.5  0.5    0.04 -0.5    -0.5             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0        Régis Gurtner             fr FRA                 GK
# 1       Bakaye Dibassy             ml MLI                 DF
# 2          Emil Krafth             se SWE                 DF
# 3    Thomas Monconduit             fr FRA                 MF
# 4  Prince-Désir Gouano             fr FRA                 DF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                         ...  \
#                  Age                90s      Gls    Sh  SoT  SoT% Sh/90  ...
# 0                 31               38.0        0   0.0  0.0   NaN  0.00  ...
# 1                 28               34.7        1  12.0  2.0  16.7  0.36  ...
# 2                 23               34.0        1  11.0  5.0  45.5  0.32  ...
# 3                 27               31.9        0  17.0  5.0  29.4  0.54  ...
# 4                 24               31.1        1   7.0  3.0  42.9  0.24  ...
#
#                       Expected                           Unnamed: 22_level_0
#    Dist   FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0   NaN  0.0  0     0      0.0  0.0     NaN  0.0     0.0             Matches
# 1  17.3  0.0  0     0      1.3  1.3    0.12 -0.3    -0.3             Matches
# 2  22.5  0.0  0     0      0.7  0.7    0.07  0.3     0.3             Matches
# 3  27.7  0.0  0     0      0.6  0.6    0.03 -0.6    -0.6             Matches
# 4  16.8  0.0  0     0      0.5  0.5    0.08  0.5     0.5             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0           Max Gradel             ci CIV              FW,MF
# 1  Christopher Jullien             fr FRA                 DF
# 2         Kelvin Amian             fr FRA                 DF
# 3      Baptiste Reynet             fr FRA                 GK
# 4      Mathieu Dossevi             tg TOG              FW,MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Standard                           \
#                  Age                90s      Gls     Sh   SoT  SoT% Sh/90
# 0                 30               38.7       13  118.0  36.0  30.5  3.05
# 1                 25               34.5        1   25.0   4.0  16.0  0.72
# 2                 20               33.3        0   18.0   4.0  22.2  0.54
# 3                 27               31.0        0    0.0   0.0   NaN  0.00
# 4                 30               28.8        5   25.0  11.0  44.0  0.87
#
#    ...                      Expected                            \
#    ...  Dist    FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG
# 0  ...  19.8  12.0  5     9     14.8  8.5    0.08 -3.8    -1.5
# 1  ...   9.6   0.0  0     0      3.1  3.1    0.13 -2.1    -2.1
# 2  ...  26.7   0.0  0     0      0.6  0.6    0.03 -0.6    -0.6
# 3  ...   NaN   0.0  0     0      0.0  0.0     NaN  0.0     0.0
# 4  ...  16.5   0.0  0     0      2.5  2.5    0.11  1.5     1.5
#
#   Unnamed: 22_level_0
#               Matches
# 0             Matches
# 1             Matches
# 2             Matches
# 3             Matches
# 4             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0         Kamil Glik             pl POL                 DF                 30
# 1           Jemerson             br BRA                 DF                 25
# 2     Radamel Falcao             co COL                 FW                 32
# 3  Aleksandr Golovin             ru RUS              FW,MF                 22
# 4    Youri Tielemans             be BEL                 MF                 21
#
#   Unnamed: 4_level_0 Standard                           ...                \
#                  90s      Gls     Sh   SoT  SoT% Sh/90  ...  Dist   FK PK
# 0               42.5        1   21.0   3.0  14.3  0.53  ...  11.1  0.0  0
# 1               34.8        0    9.0   1.0  11.1  0.28  ...  14.8  0.0  0
# 2               33.2       16  105.0  41.0  39.0  3.16  ...  16.7  8.0  3
# 3               29.5        4   54.0  19.0  35.2  1.88  ...  19.2  0.0  0
# 4               29.0        5   47.0  13.0  27.7  1.76  ...  25.2  5.0  1
#
#         Expected                            Unnamed: 22_level_0
#   PKatt       xG  npxG npxG/Sh G-xG np:G-xG             Matches
# 0     0      1.8   1.8    0.10 -0.8    -0.8             Matches
# 1     0      0.4   0.4    0.06 -0.4    -0.4             Matches
# 2     5     16.7  12.8    0.13 -1.7    -0.8             Matches
# 3     0      4.4   4.4    0.09 -1.4    -1.4             Matches
# 4     1      3.0   2.3    0.05  2.0     1.7             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0      Wesley Lautoa             nc NCL              DF,MF                 30
# 1      Júlio Tavares             cv CPV                 FW                 29
# 2     Cédric Yamberé             cf CTA                 DF                 27
# 3    Oussama Haddadi             tn TUN                 DF                 26
# 4  Romain Amalfitano             fr FRA              MF,FW                 28
#
#   Unnamed: 4_level_0 Standard                      ...                    \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist FK PK PKatt
# 0               36.8        0  15   2  13.3  0.41  ...  16.7  0  0     0
# 1               35.0        8  65  23  35.4  1.90  ...  13.7  0  2     2
# 2               34.2        0  22   4  18.2  0.68  ...  13.6  0  0     0
# 3               33.8        2  12   4  33.3  0.38  ...  19.4  0  0     0
# 4               32.6        0  22   5  22.7  0.71  ...  25.9  0  0     0
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.8  0.8    0.06 -0.8    -0.8             Matches
# 1      9.5  8.7    0.15 -4.5    -4.7             Matches
# 2      2.3  2.3    0.10 -2.3    -2.3             Matches
# 3      0.6  0.6    0.06  1.4     1.4             Matches
# 4      0.7  0.7    0.03 -0.7    -0.7             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Fayçal Fajr             ma MAR                 MF                 29
# 1        Brice Samba             fr FRA                 GK                 24
# 2  Frederic Guilbert             fr FRA                 DF                 23
# 3    Alexander Djiku             gh GHA                 DF                 23
# 4      Casimir Ninga             td CHA              FW,MF                 25
#
#   Unnamed: 4_level_0 Standard                      ...                       \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist    FK PK PKatt
# 0               39.8        5  55  16  29.1  1.41  ...  27.1  16.0  1     1
# 1               38.0        0   0   0   NaN  0.00  ...   NaN   0.0  0     0
# 2               36.5        1  13   2  15.4  0.37  ...  26.0   0.0  0     0
# 3               34.8        1   7   1  14.3  0.21  ...  11.1   0.0  0     0
# 4               28.6        8  56  20  35.7  1.97  ...  18.1   0.0  1     1
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      3.2  2.4    0.05  1.8     1.6             Matches
# 1      0.0  0.0     NaN  0.0     0.0             Matches
# 2      0.3  0.3    0.03  0.7     0.7             Matches
# 3      1.2  1.2    0.17 -0.2    -0.2             Matches
# 4      5.6  4.8    0.09  0.4     0.2             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0      Pedro Rebocho             pt POR                 DF                 23
# 1    Félix Eboa Eboa             cm CMR                 DF                 21
# 2      Jérémy Sorbon             fr FRA                 DF                 34
# 3      Marcus Thuram             fr FRA              FW,MF                 20
# 4       Ludovic Blas             fr FRA              MF,FW                 20
#
#   Unnamed: 4_level_0 Standard                      ...                    \
#                  90s      Gls  Sh SoT  SoT% Sh/90  ...  Dist FK PK PKatt
# 0               43.8        0  18   5  27.8  0.46  ...  23.9  4  0     0
# 1               34.0        3  12   5  41.7  0.41  ...   9.2  0  0     0
# 2               33.9        1   6   1  16.7  0.19  ...   8.5  0  0     0
# 3               33.5       13  60  20  33.3  2.01  ...  15.1  0  5     7
# 4               32.3        1  41   8  19.5  1.44  ...  23.2  0  1     1
#
#   Expected                           Unnamed: 22_level_0
#         xG npxG npxG/Sh G-xG np:G-xG             Matches
# 0      0.8  0.8    0.04 -0.8    -0.8             Matches
# 1      1.7  1.7    0.15  1.3     1.3             Matches
# 2      0.9  0.9    0.16  0.1     0.1             Matches
# 3     10.0  6.0    0.11 -1.0    -1.0             Matches
# 4      3.3  2.5    0.06 -2.3    -2.5             Matches
#
# [5 rows x 23 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_27807/2577412397.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   (Unnamed: 0_level_0, Player)    2630 non-null   object
#  1   (Unnamed: 1_level_0, Nation)    2628 non-null   object
#  2   (Unnamed: 2_level_0, Pos)       2630 non-null   object
#  3   (Unnamed: 3_level_0, Age)       2630 non-null   float64
#  4   (Unnamed: 4_level_0, 90s)       2630 non-null   float64
#  5   (Standard, Gls)                 2630 non-null   int64
#  6   (Standard, Sh)                  2611 non-null   float64
#  7   (Standard, SoT)                 2611 non-null   float64
#  8   (Standard, SoT%)                2230 non-null   float64
#  9   (Standard, Sh/90)               2611 non-null   float64
#  10  (Standard, SoT/90)              2611 non-null   float64
#  11  (Standard, G/Sh)                2230 non-null   float64
#  12  (Standard, G/SoT)               1959 non-null   float64
#  13  (Standard, Dist)                2179 non-null   float64
#  14  (Standard, FK)                  2541 non-null   float64
#  15  (Standard, PK)                  2630 non-null   int64
#  16  (Standard, PKatt)               2630 non-null   int64
#  17  (Expected, xG)                  2541 non-null   float64
#  18  (Expected, npxG)                2541 non-null   float64
#  19  (Expected, npxG/Sh)             2179 non-null   float64
#  20  (Expected, G-xG)                2541 non-null   float64
#  21  (Expected, np:G-xG)             2541 non-null   float64
#  22  (Unnamed: 22_level_0, Matches)  2630 non-null   object
#  23  (Club, )                        2630 non-null   object
# dtypes: float64(16), int64(3), object(5)
# memory usage: 493.3+ KB

# %%
total_df_saved = total_df.copy()

# %%
total_df = total_df_saved.copy()

# %%
total_df.shape
# Out:
# (2630, 24)

# %%
total_df.info()
total_df.rename(columns={'': 'Club'}, inplace=True)
# aceesss the sot/90 column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  2225 non-null   object
#  1           2225 non-null   object
#  2   Nation  2224 non-null   object
#  3   Pos     2225 non-null   object
#  4   Age     2225 non-null   float64
#  5   90s     2225 non-null   float64
#  6   Gls     511 non-null    float64
#  7   Sh      402 non-null    float64
#  8   SoT     402 non-null    float64
#  9   SoT%    302 non-null    float64
#  10  Sh/90   402 non-null    float64
#  11  SoT/90  402 non-null    float64
#  12  G/Sh    302 non-null    float64
#  13  G/SoT   227 non-null    float64
#  14  Dist    152 non-null    float64
# dtypes: float64(11), object(4)
# memory usage: 260.9+ KB

# %%
total_df = total_df.iloc[:, :-1]

# %%
total_df.head(10)
# Out:
#             Player             Club Nation    Pos   Age   90s  Gls     Sh  \
# 0          Ederson  Manchester City    BRA     GK  24.0  55.3    0    0.0
# 1  Aymeric Laporte  Manchester City    ESP     DF  24.0  48.3    5   36.0
# 2      Kyle Walker  Manchester City    ENG     DF  28.0  48.1    2   30.0
# 3  Raheem Sterling  Manchester City    ENG     FW  23.0  45.8   25  113.0
# 4   Bernardo Silva  Manchester City    POR  MF,FW  23.0  44.8   13   85.0
# 5      David Silva  Manchester City    ESP     MF  32.0  41.2   10   77.0
# 6   İlkay Gündoğan  Manchester City    GER     MF  27.0  38.0    6   67.0
# 7      Fernandinho  Manchester City    BRA  MF,DF  33.0  37.4    1   40.0
# 8    Sergio Agüero  Manchester City    ARG     FW  30.0  37.2   32  166.0
# 9      John Stones  Manchester City    ENG     DF  24.0  31.7    0   10.0
#
#     SoT  SoT%  ...  G/SoT  Dist   FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  \
# 0   0.0   NaN  ...    NaN   NaN  0.0   0      0   0.0   0.0      NaN   0.0
# 1   9.0  25.0  ...   0.56  15.0  0.0   0      0   3.5   3.5     0.11   1.5
# 2   6.0  20.0  ...   0.33  27.8  3.0   0      0   0.9   0.9     0.04   0.1
# 3  55.0  48.7  ...   0.45  14.2  1.0   0      0  16.7  16.7     0.17   5.3
# 4  35.0  41.2  ...   0.37  15.9  0.0   0      0   9.0   9.0     0.12   2.0
# 5  25.0  32.5  ...   0.40  13.7  5.0   0      0   9.7   9.7     0.15  -0.7
# 6  13.0  19.4  ...   0.46  20.1  4.0   0      0   4.8   4.8     0.09   1.2
# 7   8.0  20.0  ...   0.13  22.9  0.0   0      0   1.8   1.8     0.05  -0.8
# 8  67.0  40.4  ...   0.42  15.4  3.0   4      6  23.7  20.5     0.14   3.3
# 9   3.0  30.0  ...   0.00  10.1  0.0   0      0   0.8   0.8     0.11  -0.8
#
#    np:G-xG
# 0      0.0
# 1      1.5
# 2      0.1
# 3      5.3
# 4      2.0
# 5     -0.7
# 6      1.2
# 7     -0.8
# 8      3.5
# 9     -0.8
#
# [10 rows x 23 columns]

# %%
total_df.columns = total_df.columns.get_level_values(1)

# %%
total_df.rename(columns={'': 'Club'}, inplace=True)

# %%
total_df.head(810)
# Out:
#                 Player             Club Nation    Pos   Age   90s  Gls     Sh  \
# 0              Ederson  Manchester City    BRA     GK  24.0  55.3    0    0.0
# 1      Aymeric Laporte  Manchester City    ESP     DF  24.0  48.3    5   36.0
# 2          Kyle Walker  Manchester City    ENG     DF  28.0  48.1    2   30.0
# 3      Raheem Sterling  Manchester City    ENG     FW  23.0  45.8   25  113.0
# 4       Bernardo Silva  Manchester City    POR  MF,FW  23.0  44.8   13   85.0
# ..                 ...              ...    ...    ...   ...   ...  ...    ...
# 805        Stefan Bell         Mainz 05    GER     DF  26.0  27.3    0   18.0
# 806   Daniel Brosinski         Mainz 05    GER     DF  30.0  26.8    3   15.0
# 807      Robin Quaison         Mainz 05    SWE  FW,MF  24.0  25.6    9   57.0
# 808     Florian Müller         Mainz 05    GER     GK  20.0  25.0    0    0.0
# 809  Jean-Paul Boëtius         Mainz 05    NED     MF  24.0  24.0    4   47.0
#
#       SoT  SoT%  ...  G/SoT  Dist   FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  \
# 0     0.0   NaN  ...    NaN   NaN  0.0   0      0   0.0   0.0      NaN   0.0
# 1     9.0  25.0  ...   0.56  15.0  0.0   0      0   3.5   3.5     0.11   1.5
# 2     6.0  20.0  ...   0.33  27.8  3.0   0      0   0.9   0.9     0.04   0.1
# 3    55.0  48.7  ...   0.45  14.2  1.0   0      0  16.7  16.7     0.17   5.3
# 4    35.0  41.2  ...   0.37  15.9  0.0   0      0   9.0   9.0     0.12   2.0
# ..    ...   ...  ...    ...   ...  ...  ..    ...   ...   ...      ...   ...
# 805   5.0  27.8  ...   0.00  13.4  0.0   0      0   1.6   1.6     0.09  -1.6
# 806   3.0  20.0  ...   0.00  30.9  7.0   3      3   3.1   0.7     0.05  -0.1
# 807  20.0  35.1  ...   0.45  14.6  0.0   0      0   8.5   8.5     0.17  -1.5
# 808   0.0   NaN  ...    NaN   NaN  0.0   0      0   0.0   0.0      NaN   0.0
# 809  13.0  27.7  ...   0.31  21.9  1.0   0      0   2.6   2.6     0.06   1.4
#
#      np:G-xG
# 0        0.0
# 1        1.5
# 2        0.1
# 3        5.3
# 4        2.0
# ..       ...
# 805     -1.6
# 806     -0.7
# 807     -1.5
# 808      0.0
# 809      1.4
#
# [810 rows x 23 columns]

# %%
if 'Club' in total_df.columns:
    total_df.insert(1, "Club", total_df.pop("Club"))
else:
    total_df.insert(1, "Club", "")

# remove the club column
# total_df.drop(columns=['Club'], inplace=True)

#drop all rows with that have NaN values in "Sh"
# total_df.dropna(subset=['Sh'], inplace=True)

# %%
# cleaning Nation values so only the uppercase string will be kept
total_df['Nation'] = total_df['Nation'].str.split().str[1]

# %%
#print all rows which have a "Club" value of Dortmund
total_df[total_df['Club'] == 'Girona']
# Out:
#                  Player    Club Nation    Pos   Age   90s  Gls    Sh   SoT  \
# 1444  Bernardo Espinosa  Girona    COL     DF  29.0  35.0    1  17.0   6.0
# 1445             Juanpe  Girona    ESP     DF  27.0  33.2    0  21.0   6.0
# 1446              Portu  Girona    ESP  FW,MF  26.0  32.8   10  37.0  18.0
# 1447          Pere Pons  Girona    ESP     MF  25.0  31.9    1  20.0   6.0
# 1448   Cristhian Stuani  Girona    URU     FW  31.0  31.9   20  76.0  37.0
# 1449     Yassine Bounou  Girona    MAR     GK  27.0  31.8    0   1.0   0.0
# 1450       Borja García  Girona    ESP  MF,FW  27.0  30.5    1  35.0  15.0
# 1451       Álex Granell  Girona    ESP  MF,DF  29.0  30.5    2  44.0  10.0
# 1452        Pedro Porro  Girona    ESP     DF  18.0  26.6    1  25.0   7.0
# 1453       Pedro Alcalá  Girona    ESP     DF  29.0  24.3    2  18.0   5.0
# 1454      Jonás Ramalho  Girona    ESP     DF  25.0  23.0    1   7.0   2.0
# 1455       Douglas Luiz  Girona    BRA     MF  20.0  21.8    0  18.0   1.0
# 1456       Aleix García  Girona    ESP     MF  21.0  21.5    2  22.0   5.0
# 1457       Marc Muniesa  Girona    ESP  DF,MF  26.0  20.1    0   7.0   1.0
# 1458   Valery Fernández  Girona    ESP  DF,FW  18.0  14.2    1   3.0   2.0
# 1459     Anthony Lozano  Girona    HON  FW,MF  25.0  13.1    2  33.0  15.0
# 1460      Gorka Iraizoz  Girona    ESP     GK  37.0  12.2    0   0.0   0.0
# 1461        Raúl García  Girona    ESP     DF  29.0  11.4    0   9.0   2.0
# 1462     Seydou Doumbia  Girona    CIV     FW  30.0   9.7    3  21.0  11.0
# 1463    Patrick Roberts  Girona    ENG  MF,FW  21.0   7.2    0  10.0   6.0
# 1464               Aday  Girona    ESP  DF,MF  30.0   7.2    0   9.0   3.0
# 1465      Carles Planas  Girona    ESP     DF  27.0   4.7    0   1.0   0.0
# 1466      Paik Seung-ho  Girona    KOR  FW,MF  21.0   2.5    0   2.0   0.0
# 1467         Kévin Soni  Girona    CMR  FW,DF  20.0   1.9    0   5.0   1.0
# 1468        David Timor  Girona    ESP     MF  28.0   1.8    0   2.0   0.0
# 1469    Yhoan Andzouana  Girona    CGO  DF,MF  21.0   1.8    0   0.0   0.0
# 1470   Alejandro Pachón  Girona    ESP     FW  18.0   0.3    0   2.0   0.0
#
#       SoT%  ...  G/SoT  Dist   FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  \
# 1444  35.3  ...   0.17   9.1  0.0   0      0   2.1   2.1     0.14  -1.1
# 1445  28.6  ...   0.00  13.9  0.0   0      0   1.7   1.7     0.08  -1.7
# 1446  48.6  ...   0.50  13.7  0.0   1      1   7.9   7.1     0.20   1.1
# 1447  30.0  ...   0.17  21.0  0.0   0      0   1.6   1.6     0.09  -0.6
# 1448  48.7  ...   0.41  12.0  0.0   5      5  14.1  10.4     0.15   4.9
# 1449   0.0  ...    NaN   7.4  0.0   0      0   0.1   0.1     0.12  -0.1
# 1450  42.9  ...   0.07  22.2  0.0   0      0   2.0   2.0     0.06  -1.0
# 1451  22.7  ...   0.10  29.2  8.0   1      1   1.2   1.2     0.03  -1.2
# 1452  28.0  ...   0.14  22.9  0.0   0      0   1.6   1.6     0.07  -1.6
# 1453  27.8  ...   0.40  20.2  4.0   0      0   1.0   1.0     0.07   0.0
# 1454  28.6  ...   0.50  11.1  0.0   0      0   0.8   0.8     0.11   0.2
# 1455   5.6  ...   0.00  25.4  0.0   0      0   1.6   1.6     0.10  -1.6
# 1456  22.7  ...   0.40  26.5  7.0   0      0   1.5   1.5     0.08   0.5
# 1457  14.3  ...   0.00  18.9  0.0   0      0   0.5   0.5     0.07  -0.5
# 1458  66.7  ...   0.50  17.2  0.0   0      0   0.1   0.1     0.05  -0.1
# 1459  45.5  ...   0.13  14.2  0.0   0      0   2.3   2.3     0.10  -2.3
# 1460   NaN  ...    NaN   NaN  0.0   0      0   0.0   0.0      NaN   0.0
# 1461  22.2  ...   0.00  20.8  0.0   0      0   0.4   0.4     0.08  -0.4
# 1462  52.4  ...   0.27  11.4  0.0   0      0   2.7   2.7     0.18  -0.7
# 1463  60.0  ...   0.00  16.4  0.0   0      0   0.8   0.8     0.12  -0.8
# 1464  33.3  ...   0.00  27.1  2.0   0      0   0.3   0.3     0.03  -0.3
# 1465   0.0  ...    NaN  17.9  0.0   0      0   0.1   0.1     0.09  -0.1
# 1466   0.0  ...    NaN  15.5  0.0   0      0   0.1   0.1     0.05  -0.1
# 1467  20.0  ...   0.00  20.8  0.0   0      0   0.2   0.2     0.04  -0.2
# 1468   0.0  ...    NaN  34.3  0.0   0      0   0.0   0.0     0.02   0.0
# 1469   NaN  ...    NaN   NaN  NaN   0      0   NaN   NaN      NaN   NaN
# 1470   0.0  ...    NaN   NaN  NaN   0      0   NaN   NaN      NaN   NaN
#
#       np:G-xG
# 1444     -1.1
# 1445     -1.7
# 1446      0.9
# 1447     -0.6
# 1448      3.6
# 1449     -0.1
# 1450     -1.0
# 1451     -1.2
# 1452     -1.6
# 1453      0.0
# 1454      0.2
# 1455     -1.6
# 1456      0.5
# 1457     -0.5
# 1458     -0.1
# 1459     -2.3
# 1460      0.0
# 1461     -0.4
# 1462     -0.7
# 1463     -0.8
# 1464     -0.3
# 1465     -0.1
# 1466     -0.1
# 1467     -0.2
# 1468      0.0
# 1469      NaN
# 1470      NaN
#
# [27 rows x 23 columns]

# %%
# Drop rows where the value for "Min" column equals zero or is NaN
total_df = total_df[(total_df["Sh"] != 0) & (~total_df["Sh"].isna() == False)]

# %%
total_df.to_csv("t5_leagues_players_shooting.csv", index=False)
