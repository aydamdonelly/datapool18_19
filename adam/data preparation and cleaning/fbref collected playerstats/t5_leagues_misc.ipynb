# %% [markdown]
# # Aggregating all player data for in-depth analyses and comparisons

# %%
# libraries
import pandas as pd
import numpy as np
import time
import re

# %% [markdown]
# #### Getting the miscellanous stats for all players playing for clubs from the Top5 leagues in 2018/19
#
# **First, I retrieve the data (1), then I rename the lower level index to club and delete the last column (matches) and delete the higher index row. The nation row gets cleaned too**

# %%
# creating list of urls for each top5 league club from the 18-19 season
url_list = open('../urls/top5_league_clubs.txt').read().splitlines()
#read the first url
table = pd.read_html(url_list[0])

# %%
from urllib.parse import urlparse
# Initialize an empty list to store dataframes
dfs = []

# Set the delay between requests (in seconds)
delay_between_requests = 1  # Adjust this value as needed

for url in url_list:
    try:
        # Read HTML tables from the URL
        tables = pd.read_html(url, attrs={"id": "stats_misc_combined"})

        df = tables[0]
        print(tables[0].head())
        # Drop the last two rows
        df = df.iloc[:-2]
        
        # Extract club name from the URL using regex
        club_name_match = re.search(r"all_comps/(.*?)-Stats-All-Competitions", url)
        if club_name_match:
            club_name = club_name_match.group(1).replace('-', ' ')
        else:
            raise ValueError("Club name not found in URL pattern.")
        
        # Create a new column with the club name
        df['Club'] = club_name
        
        # Append the dataframe to the list
        dfs.append(df)
        
        # Introduce a delay before making the next request
        time.sleep(delay_between_requests)
    except Exception as e:
        print(f"Error reading data from {url}: {str(e)}")

# Concatenate all dataframes into one
total_df = pd.concat(dfs, ignore_index=True)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0            Ederson             br BRA                 GK                 24
# 1    Aymeric Laporte             es ESP                 DF                 24
# 2        Kyle Walker            eng ENG                 DF                 28
# 3    Raheem Sterling            eng ENG                 FW                 23
# 4     Bernardo Silva             pt POR              MF,FW                 23
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               55.3           3    0     0   2   5  ...   3    3     0     2
# 1               48.3           5    0     0  40  26  ...  59   31     0     1
# 2               48.1           6    0     0  27  22  ...  48   34     0     1
# 3               45.8           5    0     0  63  59  ...  27   25     4     0
# 4               44.8           3    0     0  45  32  ...  36   52     2     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won  Lost   Won%             Matches
# 0  0   78.0         14.0   0.0  100.0             Matches
# 1  0  225.0        102.0  69.0   59.6             Matches
# 2  0  209.0         54.0  29.0   65.1             Matches
# 3  0  156.0         18.0  31.0   36.7             Matches
# 4  0  200.0         12.0  31.0   27.9             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0            Alisson             br BRA                 GK                 25
# 1    Virgil van Dijk             nl NED                 DF                 27
# 2      Mohamed Salah             eg EGY                 FW                 26
# 3         Sadio Mané             sn SEN                 FW                 26
# 4   Andrew Robertson            sct SCO                 DF                 24
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               51.0           1    0     0   0   1  ...   2    1     0     0
# 1               49.6           4    0     0  20  27  ...  50   36     0     1
# 2               48.1           2    0     0  43  49  ...   9   12     5     0
# 3               47.7           4    0     0  59  89  ...  20   45     3     0
# 4               46.9           7    0     0  29  17  ...  36   63     0     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won   Lost  Won%             Matches
# 0  0   92.0         13.0    1.0  92.9             Matches
# 1  0  246.0        215.0   86.0  71.4             Matches
# 2  0  169.0         15.0   78.0  16.1             Matches
# 3  0  195.0         53.0  107.0  33.1             Matches
# 4  0  292.0         29.0   34.0  46.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0  Kepa Arrizabalaga             es ESP                 GK                 23
# 1  César Azpilicueta             es ESP                 DF                 28
# 2           Jorginho             it ITA                 MF                 26
# 3         David Luiz             br BRA                 DF                 31
# 4       N'Golo Kanté             fr FRA                 MF                 27
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               55.0           4    0     0   1   6  ...   0    1     0     1
# 1               54.4           7    0     0  52  26  ...  71   83     2     1
# 2               49.0          10    0     0  47  40  ...  86   55     0     0
# 3               48.6           5    0     0  46  38  ...  46   39     0     0
# 4               46.8           6    0     0  49  25  ...  54   65     0     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won  Lost   Won%             Matches
# 0  0   77.0         10.0   0.0  100.0             Matches
# 1  0  238.0         84.0  59.0   58.7             Matches
# 2  0  335.0         19.0  30.0   38.8             Matches
# 3  0  239.0         99.0  80.0   55.3             Matches
# 4  0  298.0         28.0  52.0   35.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0  Toby Alderweireld             be BEL                 DF                 29
# 1  Christian Eriksen             dk DEN              MF,FW                 26
# 2        Hugo Lloris             fr FRA                 GK                 31
# 3     Moussa Sissoko             fr FRA                 MF                 28
# 4         Harry Kane            eng ENG                 FW                 25
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               49.1           5    0     0  18   4  ...  38   32     0     0
# 1               46.2           4    0     0  22  27  ...  30   32     0     0
# 2               43.9           0    1     0   1   2  ...   0    0     0     0
# 3               37.7           5    0     0  49  26  ...  30   44     0     1
# 4               37.1           6    0     0  42  78  ...   3   13     2     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won  Lost   Won%             Matches
# 0  1  244.0         78.0  73.0   51.7             Matches
# 1  0  245.0         15.0  46.0   24.6             Matches
# 2  0   44.0         11.0   0.0  100.0             Matches
# 3  0  271.0         25.0  26.0   49.0             Matches
# 4  0   78.0         66.0  94.0   41.3             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#           Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                       Player             Nation                Pos
# 0  Pierre-Emerick Aubameyang             ga GAB                 FW
# 1               Granit Xhaka             ch SUI              MF,DF
# 2  Sokratis Papastathopoulos             gr GRE                 DF
# 3           Shkodran Mustafi             de GER                 DF
# 4        Alexandre Lacazette             fr FRA                 FW
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 29               42.8           1    0     0  26  33  ...
# 1                 25               38.2          13    0     0  68  66  ...
# 2                 30               37.5          13    1     1  47  30  ...
# 3                 26               37.0           9    0     0  51  10  ...
# 4                 27               37.0           4    1     0  71  76  ...
#
#                                  Aerial Duels              Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG  Recov          Won   Lost  Won%             Matches
# 0  12   20     1     0  0   95.0         48.0  111.0  30.2             Matches
# 1  45   40     0     2  0  261.0         63.0   48.0  56.8             Matches
# 2  41   37     0     1  0  153.0         74.0   53.0  58.3             Matches
# 3  67   50     0     2  0  140.0        141.0   62.0  69.5             Matches
# 4  17   24     1     0  0   92.0         54.0  117.0  31.6             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0       David de Gea             es ESP                 GK                 27
# 1         Paul Pogba             fr FRA                 MF                 25
# 2          Luke Shaw            eng ENG                 DF                 23
# 3       Ashley Young            eng ENG                 DF                 33
# 4    Victor Lindelöf             se SWE                 DF                 24
#
#   Unnamed: 4_level_0 Performance                      ...                 \
#                  90s        CrdY CrdR 2CrdY Fls  Fld  ... Int TklW PKwon
# 0               47.0           1    0     0   1    4  ...   0    0     0
# 1               44.5           7    1     1  69  101  ...  26   38     1
# 2               39.8          14    0     0  60   25  ...  37   41     0
# 3               39.3          13    1     1  57   40  ...  66   44     0
# 4               38.9           3    0     0  23   16  ...  33   31     0
#
#                   Aerial Duels              Unnamed: 21_level_0
#   PKcon OG  Recov          Won  Lost   Won%             Matches
# 0     0  0   50.0          3.0   0.0  100.0             Matches
# 1     0  0  263.0         70.0  60.0   53.8             Matches
# 2     0  1  175.0         53.0  29.0   64.6             Matches
# 3     0  0  199.0         21.0  14.0   60.0             Matches
# 4     0  1  177.0         77.0  46.0   62.6             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Conor Coady            eng ENG                 DF                 25
# 1       Matt Doherty             ie IRL              DF,MF                 26
# 2         Willy Boly             ci CIV                 DF                 27
# 3       Raúl Jiménez             mx MEX                 FW                 27
# 4       Ryan Bennett            eng ENG                 DF                 28
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               46.7           6    0     0  16   9  ...  35   21     0     0
# 1               41.3           5    0     0  35  24  ...  63   46     2     0
# 2               40.5           3    1     0  32  14  ...  81   58     0     0
# 3               39.3           4    0     0  49  42  ...  29   20     1     0
# 4               38.9          12    0     0  40  13  ...  46   32     0     2
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won   Lost  Won%             Matches
# 0  3  251.0         32.0   23.0  58.2             Matches
# 1  1  166.0        145.0  101.0  58.9             Matches
# 2  0  213.0        136.0   62.0  68.7             Matches
# 3  0  139.0         77.0  104.0  42.5             Matches
# 4  0  133.0        119.0   93.0  56.1             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0     Jordan Pickford            eng ENG                 GK
# 1    Gylfi Sigurðsson             is ISL                 MF
# 2       Michael Keane            eng ENG                 DF
# 3         Lucas Digne             fr FRA                 DF
# 4  Idrissa Gana Gueye             sn SEN                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 24               40.0           1    0     0   1   4  ...
# 1                 28               37.2           3    0     0  37  39  ...
# 2                 25               35.3           2    0     0  23   7  ...
# 3                 25               34.9           6    1     0  42  33  ...
# 4                 28               33.4           7    0     0  55  41  ...
#
#                                  Aerial Duels              Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG  Recov          Won   Lost  Won%             Matches
# 0   0    0     0     1  0   19.0         11.0    1.0  91.7             Matches
# 1  31   38     0     0  0  157.0         19.0   40.0  32.2             Matches
# 2  44   26     0     0  0  161.0        191.0  122.0  61.0             Matches
# 3  61   46     0     0  1  181.0         87.0   43.0  66.9             Matches
# 4  75   95     0     1  0  254.0         32.0   35.0  47.8             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0      Wilfred Ndidi             ng NGA                 MF                 21
# 1  Kasper Schmeichel             dk DEN                 GK                 31
# 2    Ricardo Pereira             pt POR              DF,FW                 24
# 3       Ben Chilwell            eng ENG                 DF                 21
# 4     James Maddison            eng ENG              MF,FW                 21
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               39.3           8    0     0  49  25  ...  86  100     0     0
# 1               38.0           3    0     0   0   4  ...   3    1     0     0
# 2               36.5           7    0     0  41  51  ...  60   67     1     1
# 3               36.0           4    0     0  32  44  ...  38   29     0     0
# 4               32.7           4    1     1  26  81  ...  12   32     2     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won   Lost  Won%             Matches
# 0  0  324.0        128.0  107.0  54.5             Matches
# 1  0   38.0         10.0    1.0  90.9             Matches
# 2  0  216.0         66.0   73.0  47.5             Matches
# 3  0  185.0        108.0   71.0  60.3             Matches
# 4  0  126.0         11.0   34.0  24.4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0   Łukasz Fabiański             pl POL                 GK                 33
# 1          Issa Diop             fr FRA                 DF                 21
# 2        Declan Rice            eng ENG                 MF                 19
# 3    Felipe Anderson             br BRA              MF,FW                 25
# 4   Robert Snodgrass            sct SCO                 MF                 30
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               38.0           0    0     0   0   6  ...   1    0     0     0
# 1               38.0           5    0     0  24  18  ...  67   40     0     0
# 2               37.3           4    0     0  17   7  ...  57   64     0     0
# 3               35.4           3    0     0  29  55  ...  41   50     0     1
# 4               28.5          10    0     0  39  56  ...  12   28     0     1
#
#             Aerial Duels             Unnamed: 21_level_0
#   OG  Recov          Won  Lost  Won%             Matches
# 0  0   31.0          9.0   2.0  81.8             Matches
# 1  1  172.0         75.0  49.0  60.5             Matches
# 2  0  287.0         54.0  41.0  56.8             Matches
# 3  0  227.0          9.0  26.0  25.7             Matches
# 4  0  133.0         25.0  35.0  41.7             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Craig Cathcart            nir NIR                 DF
# 1          Ben Foster            eng ENG                 GK
# 2  Abdoulaye Doucouré             ml MLI                 MF
# 3      Étienne Capoue             fr FRA                 MF
# 4     Roberto Pereyra             ar ARG                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 29               40.1           3    0     0  18  11  ...
# 1                 35               38.0           1    0     0   2   9  ...
# 2                 25               37.6           9    0     0  41  14  ...
# 3                 30               37.6          15    1     0  58  58  ...
# 4                 27               34.3           3    0     0  29  41  ...
#
#                                  Aerial Duels              Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG  Recov          Won  Lost   Won%             Matches
# 0  43   35     0     0  2  160.0         86.0  79.0   52.1             Matches
# 1   2    2     0     2  0   64.0         13.0   0.0  100.0             Matches
# 2  35   40     0     0  1  257.0         40.0  36.0   52.6             Matches
# 3  95   62     0     0  0  256.0         63.0  49.0   56.3             Matches
# 4  26   17     1     0  0  185.0          4.0  19.0   17.4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0     Luka Milivojević             rs SRB                 MF
# 1      Andros Townsend            eng ENG              FW,MF
# 2    Aaron Wan-Bissaka            eng ENG                 DF
# 3  Patrick van Aanholt             nl NED                 DF
# 4        Wilfried Zaha             ci CIV                 FW
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                      ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls  Fld  ...
# 0                 27               40.4          11    0     0  64   42  ...
# 1                 27               39.5           1    0     0  12   62  ...
# 2                 20               38.6           4    1     0  28   19  ...
# 3                 27               38.4           3    0     0  13   18  ...
# 4                 25               35.7          10    1     1  50  108  ...
#
#                                  Aerial Duels             Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG  Recov          Won  Lost  Won%             Matches
# 0  76   73     0     0  0  194.0         54.0  37.0  59.3             Matches
# 1  42   39     1     0  0  193.0          4.0  12.0  25.0             Matches
# 2  85   92     0     1  0  206.0         43.0  30.0  58.9             Matches
# 3  42   24     0     1  0  216.0         10.0  12.0  45.5             Matches
# 4  11   21     6     0  0  135.0          9.0  34.0  20.9             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0    Martin Dúbravka             sk SVK                 GK                 29
# 1       Matt Ritchie            sct SCO              DF,MF                 28
# 2        Ayoze Pérez             es ESP              MF,FW                 25
# 3   Jamaal Lascelles            eng ENG                 DF                 24
# 4     Salomón Rondón             ve VEN                 FW                 28
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               38.0           1    0     0   0   5  ...   0    0     0     0
# 1               35.5          10    0     0  60  42  ...  56   46     0     0
# 2               33.3           3    0     0  46  44  ...  43   24     1     0
# 3               31.6           4    0     0  17  10  ...  41   22     0     0
# 4               29.0           1    0     0  22  26  ...   5    3     1     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won   Lost  Won%             Matches
# 0  0   38.0         15.0    2.0  88.2             Matches
# 1  0  171.0         32.0   65.0  33.0             Matches
# 2  0  169.0         26.0   78.0  25.0             Matches
# 3  0  180.0         92.0   45.0  67.2             Matches
# 4  0  108.0        146.0  232.0  38.6             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0         Nathan Aké             nl NED                 DF                 23
# 1        Ryan Fraser            sct SCO              MF,FW                 24
# 2         Steve Cook            eng ENG                 DF                 27
# 3        Joshua King             no NOR              FW,MF                 26
# 4    Jefferson Lerma             co COL                 MF                 23
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               38.9           3    0     0  28  21  ...  36   37     1     1
# 1               37.5           2    0     0   7  68  ...  22   11     1     0
# 2               34.2           4    0     0  20  31  ...  52   21     0     1
# 3               33.6           3    0     0  55  46  ...   7   20     2     0
# 4               29.8          12    0     0  50  52  ...  54   31     1     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won   Lost  Won%             Matches
# 0  0  182.0         86.0   66.0  56.6             Matches
# 1  0  135.0          9.0   27.0  25.0             Matches
# 2  1  144.0        121.0   75.0  61.7             Matches
# 3  0  148.0         88.0  116.0  43.1             Matches
# 4  1  233.0         75.0   67.0  52.8             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0            Ben Mee            eng ENG                 DF                 28
# 1     Charlie Taylor            eng ENG                 DF                 24
# 2          Jack Cork            eng ENG                 MF                 29
# 3    James Tarkowski            eng ENG                 DF                 25
# 4    Ashley Westwood            eng ENG                 MF                 28
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               39.0           9    0     0  29  18  ...  48   24     0     1
# 1               38.0           2    0     0  15  48  ...  41   26     0     0
# 2               37.4           6    0     0  30  38  ...  29   28     0     0
# 3               36.3           8    0     0  36  33  ...  43   37     0     0
# 4               32.5           6    0     0  32  24  ...  47   30     0     0
#
#             Aerial Duels              Unnamed: 21_level_0
#   OG  Recov          Won   Lost  Won%             Matches
# 0  2  246.0        148.0  102.0  59.2             Matches
# 1  0  205.0         70.0   60.0  53.8             Matches
# 2  0  219.0         51.0   78.0  39.5             Matches
# 3  0  134.0        164.0   76.0  68.3             Matches
# 4  0  234.0         19.0   18.0  51.4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Nathan Redmond            eng ENG              MF,FW
# 1     Pierre Højbjerg             dk DEN                 MF
# 2        Jan Bednarek             pl POL                 DF
# 3  Jannik Vestergaard             dk DEN                 DF
# 4         Oriol Romeu             es ESP                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 24               40.9           3    0     0  31  32  ...
# 1                 22               33.3           8    2     1  49  51  ...
# 2                 22               26.2           9    0     0  22   7  ...
# 3                 25               26.2           2    0     0  18  15  ...
# 4                 26               25.8          11    0     0  51  18  ...
#
#                                  Aerial Duels             Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG  Recov          Won  Lost  Won%             Matches
# 0  22   25     0     0  0  171.0         25.0  64.0  28.1             Matches
# 1  60   49     0     0  0  269.0         47.0  29.0  61.8             Matches
# 2  71   25     0     0  0  129.0         79.0  60.0  56.8             Matches
# 3  38   34     0     0  0  123.0         85.0  51.0  62.5             Matches
# 4  53   49     0     0  0  185.0         47.0  37.0  56.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Shane Duffy             ie IRL                 DF                 26
# 1         Lewis Dunk            eng ENG                 DF                 26
# 2        Mathew Ryan             au AUS                 GK                 26
# 3      Dale Stephens            eng ENG                 MF                 29
# 4       Davy Pröpper             nl NED                 MF                 26
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               39.6           4    1     0  23  12  ...  45   23     1     1
# 1               37.3           7    1     1  24  18  ...  49   26     0     0
# 2               36.3           2    0     0   1   4  ...   0    0     0     1
# 3               32.6           7    1     0  50  11  ...  52   63     0     0
# 4               31.6           2    0     0  33  18  ...  55   32     0     1
#
#             Aerial Duels             Unnamed: 21_level_0
#   OG  Recov          Won  Lost  Won%             Matches
# 0  0  143.0        187.0  68.0  73.3             Matches
# 1  0  206.0        119.0  63.0  65.4             Matches
# 2  0   25.0          8.0   1.0  88.9             Matches
# 3  0  199.0         26.0  22.0  54.2             Matches
# 4  0  191.0         36.0  26.0  58.1             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0  Bruno Ecuele Manga             ga GAB                 DF
# 1      Neil Etheridge             ph PHI                 GK
# 2       Sean Morrison            eng ENG                 DF
# 3         Joe Bennett            eng ENG                 DF
# 4     Víctor Camarasa             es ESP                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 30               39.5           0    0     0  18  14  ...
# 1                 28               38.0           2    0     0   0   5  ...
# 2                 27               34.8           6    0     0  33  23  ...
# 3                 28               30.3           5    0     0  21  35  ...
# 4                 24               29.3           6    0     0  23  29  ...
#
#                                  Aerial Duels                \
#   Int TklW PKwon PKcon OG  Recov          Won   Lost   Won%
# 0  81   36     0     2  0  268.0         87.0   60.0   59.2
# 1   7    1     0     0  0   33.0          7.0    0.0  100.0
# 2  52   17     0     3  0  152.0        225.0  113.0   66.6
# 3  60   29     0     0  0  129.0         34.0   17.0   66.7
# 4  33   15     0     0  0  168.0         19.0   31.0   38.0
#
#   Unnamed: 21_level_0
#               Matches
# 0             Matches
# 1             Matches
# 2             Matches
# 3             Matches
# 4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0  Aleksandar Mitrović             rs SRB                 FW
# 1          Sergio Rico             es ESP                 GK
# 2           Denis Odoi             gh GHA                 DF
# 3       Calum Chambers            eng ENG              MF,DF
# 4       Ryan Sessegnon            eng ENG              FW,DF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 23               37.5           7    0     0  63  60  ...
# 1                 24               32.0           1    0     0   1   5  ...
# 2                 30               31.1           5    0     0  43  32  ...
# 3                 23               30.8           9    0     0  35   5  ...
# 4                 18               27.8           1    0     0  23  22  ...
#
#                                  Aerial Duels              Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG  Recov          Won   Lost  Won%             Matches
# 0   6    9     1     1  0   83.0        235.0  239.0  49.6             Matches
# 1   1    1     0     1  0   26.0         13.0    1.0  92.9             Matches
# 2  43   34     0     1  1  191.0         55.0   51.0  51.9             Matches
# 3  69   36     0     0  0  233.0         64.0   54.0  54.2             Matches
# 4  19   15     0     1  0  138.0         18.0   40.0  31.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#       Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Player             Nation                Pos
# 0  Christopher Schindler             de GER                 DF
# 1            Jonas Lössl             dk DEN                 GK
# 2        Terence Kongolo             nl NED                 DF
# 3          Jonathan Hogg            eng ENG                 MF
# 4             Aaron Mooy             au AUS              MF,FW
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 28               37.2           5    1     1  26  18  ...
# 1                 29               31.9           1    0     0   0   3  ...
# 2                 24               30.2           4    0     0  20  25  ...
# 3                 29               27.3           8    1     0  62  36  ...
# 4                 27               26.1           4    0     0  26  12  ...
#
#                                 Aerial Duels            Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG Recov          Won Lost  Won%             Matches
# 0  70   36     0     1  0   122          136  108  55.7             Matches
# 1   2    0     0     0  0    41           13    5  72.2             Matches
# 2  65   46     0     1  1   121           53   35  60.2             Matches
# 3  73   41     0     0  0   234           31   33  48.4             Matches
# 4  14   42     0     0  0   203           14   26  35.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Joshua Kimmich             de GER              DF,MF
# 1  Robert Lewandowski             pl POL                 FW
# 2         David Alaba             at AUT                 DF
# 3         Niklas Süle             de GER                 DF
# 4    Thiago Alcántara             es ESP                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 23               47.6           7    0     0  34  78  ...
# 1                 29               46.4           6    0     0  48  72  ...
# 2                 26               40.4           4    0     0  18  12  ...
# 3                 22               39.0           3    1     0  23   7  ...
# 4                 27               38.1           6    0     0  67  45  ...
#
#                                 Aerial Duels            Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG Recov          Won Lost  Won%             Matches
# 0  51   38     1     0  0   259           29   32  47.5             Matches
# 1  15   13     2     0  0    85           76  101  42.9             Matches
# 2  53   33     0     0  0   181           40   24  62.5             Matches
# 3  55   32     0     0  0   215           96   30  76.2             Matches
# 4  72   83     1     1  0   309           41   42  49.4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Axel Witsel             be BEL                 MF                 29
# 1        Roman Bürki             ch SUI                 GK                 27
# 2       Abdou Diallo             sn SEN                 DF                 22
# 3         Marco Reus             de GER              MF,FW                 29
# 4       Jadon Sancho            eng ENG              FW,MF                 18
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               41.2           3    0     0  33  58  ...  58   43   0.0   0.0
# 1               40.3           1    0     0   0   9  ...   2    0   0.0   0.0
# 2               36.1           2    1     0  29  13  ...  36   32   0.0   0.0
# 3               33.8           4    1     0  43  43  ...  19   34   2.0   1.0
# 4               33.0           3    0     0   6  44  ...  15   13   2.0   0.0
#
#             Aerial Duels             Unnamed: 21_level_0
#   OG  Recov          Won  Lost  Won%             Matches
# 0  0  275.0         57.0  34.0  62.6             Matches
# 1  0   74.0          7.0   1.0  87.5             Matches
# 2  0  196.0         61.0  48.0  56.0             Matches
# 3  0  110.0         25.0  35.0  41.7             Matches
# 4  0  160.0          1.0  23.0   4.2             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0       Péter Gulácsi             hu HUN                 GK
# 1     Ibrahima Konaté             fr FRA                 DF
# 2      Yussuf Poulsen             dk DEN                 FW
# 3     Marcel Sabitzer             at AUT              MF,FW
# 4  Marcel Halstenberg             de GER                 DF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 28               38.8           0    0     0   0   2  ...
# 1                 19               35.4           8    0     0  51  39  ...
# 2                 24               34.9           3    0     0  74  66  ...
# 3                 24               34.5          10    0     0  37  40  ...
# 4                 26               34.4           4    0     0  30  28  ...
#
#                                 Aerial Duels             Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG Recov          Won Lost   Won%             Matches
# 0   1    0     0     0  0    60            7    0  100.0             Matches
# 1  75   43     0     1  0   161          103   38   73.0             Matches
# 2   8   12     0     0  0   113          156  153   50.5             Matches
# 3  37   40     0     0  1   210           21   28   42.9             Matches
# 4  52   57     1     0  0   183           78   37   67.8             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Lukáš Hrádecký             fi FIN                 GK                 28
# 1        Kai Havertz             de GER              MF,FW                 19
# 2       Jonathan Tah             de GER                 DF                 22
# 3      Kevin Volland             de GER              FW,MF                 26
# 4      Julian Brandt             de GER              MF,FW                 22
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               40.0           1    0     0   0   3  ...   2    0     0     0
# 1               38.8           2    0     0  32  62  ...  21   22     0     0
# 2               37.6           3    0     0  18  13  ...  49   35     0     2
# 3               37.5           5    0     0  47  61  ...   8   23     3     1
# 4               37.0           0    0     0  19  27  ...  24   20     0     0
#
#            Aerial Duels            Unnamed: 21_level_0
#   OG Recov          Won Lost  Won%             Matches
# 0  0    78            7    1  87.5             Matches
# 1  0   183           61   67  47.7             Matches
# 2  0   289           79   34  69.9             Matches
# 3  0   103           38   64  37.3             Matches
# 4  0   220           38   38  50.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0        Yann Sommer             ch SUI                 GK                 29
# 1     Thorgan Hazard             be BEL              FW,MF                 25
# 2        Oscar Wendt             se SWE                 DF                 32
# 3        Nico Elvedi             ch SUI                 DF                 21
# ...
# 4  ...  29.0  13.0   0.0   1.0  0  201.0         15.0  19.0  44.1
#
#   Unnamed: 21_level_0
#               Matches
# 0             Matches
# 1             Matches
# 2             Matches
# 3             Matches
# 4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Andrea Petagna             it ITA                 FW                 23
# 1      Mohamed Fares             dz ALG                 DF                 22
# 2     Manuel Lazzari             it ITA                 DF                 24
# 3   Simone Missiroli             it ITA                 MF                 32
# 4      Thiago Cionek             pl POL                 DF                 32
#
#   Unnamed: 4_level_0 Performance                         ...              \
#                  90s        CrdY CrdR 2CrdY   Fls   Fld  ...   Int  TklW
# 0               34.4           8    0     0  44.0  46.0  ...   4.0   6.0
# 1               33.8          12    0     0  51.0  40.0  ...  54.0  43.0
# 2               32.5           8    0     0  28.0  61.0  ...  20.0  17.0
# 3               30.5           9    0     0  30.0  55.0  ...  46.0  43.0
# 4               30.2          13    2     0  52.0  37.0  ...  55.0  44.0
#
#                         Aerial Duels             Unnamed: 21_level_0
#   PKwon PKcon OG  Recov          Won  Lost  Won%             Matches
# 0   1.0   0.0  0   78.0         37.0  64.0  36.6             Matches
# 1   0.0   1.0  0  153.0         41.0  34.0  54.7             Matches
# 2   1.0   0.0  0  142.0          9.0  21.0  30.0             Matches
# 3   0.0   0.0  0  191.0         67.0  64.0  51.1             Matches
# 4   1.0   2.0  0  177.0         61.0  52.0  54.0             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0    Simone Iacoponi             it ITA                 DF                 31
# 1         Luigi Sepe             it ITA                 GK                 27
# 2  Riccardo Gagliolo             se SWE                 DF                 28
# 3        Bruno Alves             pt POR                 DF                 36
# 4   Antonino Barillà             it ITA                 MF                 30
#
#   Unnamed: 4_level_0 Performance                         ...              \
#                  90s        CrdY CrdR 2CrdY   Fls   Fld  ...   Int  TklW
# 0               38.2           4    0     0  34.0  30.0  ...  37.0  43.0
# 1               38.0           1    0     0   0.0   3.0  ...   3.0   1.0
# 2               34.8           8    0     0  32.0  41.0  ...  66.0  45.0
# 3               32.5           9    1     1  31.0  12.0  ...  29.0   8.0
# 4               30.1          10    0     0  67.0  32.0  ...  36.0  36.0
#
#                         Aerial Duels             Unnamed: 21_level_0
#   PKwon PKcon OG  Recov          Won  Lost  Won%             Matches
# 0   0.0   1.0  0  151.0         55.0  59.0  48.2             Matches
# 1   0.0   0.0  1   31.0         12.0   2.0  85.7             Matches
# 2   0.0   2.0  2  183.0         42.0  38.0  52.5             Matches
# 3   0.0   1.0  1  129.0        102.0  38.0  72.9             Matches
# 4   1.0   0.0  0  151.0         22.0  42.0  34.4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 0      Alessio Cragno             it ITA                 GK
# 1      Nicolò Barella             it ITA                 MF
# 2        Artur Ioniță             md MDA                 MF
# 3  Leonardo Pavoletti             it ITA                 FW
# 4          João Pedro             it ITA              FW,MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                         \
#                  Age                90s        CrdY CrdR 2CrdY   Fls   Fld
# 0                 24               40.0           1    0     0   0.0   7.0
# 1                 21               37.5          10    2     2  60.0  82.0
# 2                 27               34.8           4    1     0  67.0  13.0
# 3                 29               32.1           6    0     0  80.0  34.0
# 4                 26               29.7           5    1     1  48.0  53.0
#
#    ...                                   Aerial Duels               \
#    ...   Int  TklW PKwon PKcon OG  Recov          Won   Lost  Won%
# 0  ...   2.0   0.0   0.0   0.0  0   39.0         13.0    1.0  92.9
# 1  ...  38.0  65.0   0.0   2.0  0  253.0         19.0   47.0  28.8
# 2  ...  27.0  38.0   1.0   0.0  0  145.0         91.0   76.0  54.5
# 3  ...   7.0  21.0   0.0   0.0  0   88.0        230.0  141.0  62.0
# 4  ...   6.0  12.0   1.0   0.0  0   79.0         68.0   86.0  44.2
#
#   Unnamed: 21_level_0
#               Matches
# 0             Matches
# 1             Matches
# 2             Matches
# 3             Matches
# 4             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0  Cristiano Biraghi             it ITA                 DF                 25
# 1    Federico Chiesa             it ITA                 FW                 20
# 2       Alban Lafont             fr FRA                 GK                 19
# 3  Nikola Milenković             rs SRB                 DF                 20
# 4    Jordan Veretout             fr FRA                 MF                 25
#
#   Unnamed: 4_level_0 Performance                     ...                       \
#                  90s        CrdY CrdR 2CrdY Fls Fld  ... Int TklW PKwon PKcon
# 0               39.5           9    0     0  36  26  ...  44   33     0     0
# 1               37.6           4    0     0  56  59  ...  10   27     4     0
# 2               37.5           2    0     0   0   8  ...   1    0     0     0
# 3               37.4           9    1     1  60  19  ...  48   40     0     0
# 4               36.7          13    1     0  51  38  ...  46   40     0     0
#
#            Aerial Duels             Unnamed: 21_level_0
#   OG Recov          Won Lost   Won%             Matches
# 0  0   162           39   16   70.9             Matches
# 1  0   143           14   47   23.0             Matches
# 2  1    39            3    0  100.0             Matches
# 3  0   144          107   66   61.8             Matches
# 4  0   265           25   41   37.9             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0  Domenico Criscito             it ITA                 DF                 31
# 1   Christian Kouamé             ci CIV                 FW                 20
# 2    Davide Biraschi             it ITA                 DF                 24
# 3         Ionuț Radu             ro ROU                 GK                 21
# 4      Darko Lazović             rs SRB              DF,FW                 27
#
#   Unnamed: 4_level_0 Performance                         ...              \
#                  90s        CrdY CrdR 2CrdY   Fls   Fld  ...   Int  TklW
# 0               35.1          12    1     0  47.0  49.0  ...  70.0  75.0
# 1               35.1           4    0     0  36.0  82.0  ...  25.0  22.0
# 2               33.9           3    1     0  37.0  31.0  ...  64.0  38.0
# 3               33.0           0    0     0   0.0   2.0  ...   1.0   0.0
# 4               29.2           2    0     0  15.0  14.0  ...  20.0  17.0
#
#                         Aerial Duels              Unnamed: 21_level_0
#   PKwon PKcon OG  Recov          Won   Lost  Won%             Matches
# 0   0.0   1.0  0  221.0         44.0   38.0  53.7             Matches
# 1   0.0   0.0  0  126.0        195.0  171.0  53.3             Matches
# 2   0.0   1.0  1  190.0         61.0   51.0  54.5             Matches
# 3   0.0   0.0  0   31.0         13.0    2.0  86.7             Matches
# 4   0.0   0.0  0  126.0         16.0   21.0  43.2             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0     Francesco Caputo             it ITA                 FW
# 1  Giovanni Di Lorenzo             it ITA              DF,FW
# 2     Matías Silvestre             ar ARG                 DF
# 3      Ismaël Bennacer             dz ALG                 MF
# 4          Rade Krunić             ba BIH                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Performance                     ...  \
#                  Age                90s        CrdY CrdR 2CrdY Fls Fld  ...
# 0                 30               39.0           3    0     0  28  35  ...
# 1                 24               38.0           8    0     0  46  54  ...
# 2                 33               35.0           6    0     0  22  21  ...
# 3                 20               33.5           7    0     0  46  59  ...
# 4                 24               31.6           7    1     0  47  76  ...
#
#                                 Aerial Duels            Unnamed: 21_level_0
#   Int TklW PKwon PKcon OG Recov          Won Lost  Won%             Matches
# 0   2    9     2     0  0    79           24   56  30.0             Matches
# 1  36   43     0     0  0   189           37   36  50.7             Matches
# 2  21   17     0     0  1   111           87   44  66.4             Matches
# 3  57   57     0     1  0   312           32   29  52.5             Matches
# 4  24   23     0     0  0   151           50   84  37.3             Matches
#
# [5 rows x 22 columns]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_48371/3743060544.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club'] = club_name
# Error reading data from https://fbref.com/en/squads/6a7ad59d/2018-2019/all_comps/Frosinone-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/cc919b35/2018-2019/all_comps/Chievo-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/e2d8892c/2018-2019/all_comps/Paris-Saint-Germain-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/cb188c0c/2018-2019/all_comps/Lille-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/d53c0b06/2018-2019/all_comps/Lyon-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/d298ef2c/2018-2019/all_comps/Saint-Etienne-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/5725cc7b/2018-2019/all_comps/Marseille-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/281b0e73/2018-2019/all_comps/Montpellier-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/132ebc33/2018-2019/all_comps/Nice-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/7fdd64e0/2018-2019/all_comps/Reims-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/1cbf5f9e/2018-2019/all_comps/Nimes-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/b3072e00/2018-2019/all_comps/Rennes-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/c0d3eab4/2018-2019/all_comps/Strasbourg-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/d7a486cd/2018-2019/all_comps/Nantes-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/69236f98/2018-2019/all_comps/Angers-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/123f3efe/2018-2019/all_comps/Bordeaux-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/25622401/2018-2019/all_comps/Amiens-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/3f8c4b5f/2018-2019/all_comps/Toulouse-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/fd6114db/2018-2019/all_comps/Monaco-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/8dfb7350/2018-2019/all_comps/Dijon-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/74229020/2018-2019/all_comps/Caen-Stats-All-Competitions: HTTP Error 429: Too Many Requests
# Error reading data from https://fbref.com/en/squads/d41b5f53/2018-2019/all_comps/Guingamp-Stats-All-Competitions: HTTP Error 429: Too Many Requests

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   (Unnamed: 0_level_0, Player)    2630 non-null   object
#  1   (Unnamed: 1_level_0, Nation)    2628 non-null   object
#  2   (Unnamed: 2_level_0, Pos)       2630 non-null   object
#  3   (Unnamed: 3_level_0, Age)       2630 non-null   float64
#  4   (Unnamed: 4_level_0, 90s)       2630 non-null   float64
#  5   (Performance, CrdY)             2630 non-null   int64
#  6   (Performance, CrdR)             2630 non-null   int64
#  7   (Performance, 2CrdY)            2630 non-null   int64
#  8   (Performance, Fls)              2611 non-null   float64
#  9   (Performance, Fld)              2611 non-null   float64
#  10  (Performance, Off)              2611 non-null   float64
#  11  (Performance, Crs)              2611 non-null   float64
#  12  (Performance, Int)              2611 non-null   float64
#  13  (Performance, TklW)             2611 non-null   float64
#  14  (Performance, PKwon)            2609 non-null   float64
#  15  (Performance, PKcon)            2609 non-null   float64
#  16  (Performance, OG)               2630 non-null   int64
#  17  (Performance, Recov)            2541 non-null   float64
#  18  (Aerial Duels, Won)             2541 non-null   float64
#  19  (Aerial Duels, Lost)            2541 non-null   float64
#  20  (Aerial Duels, Won%)            2463 non-null   float64
#  21  (Unnamed: 21_level_0, Matches)  2630 non-null   object
#  22  (Club, )                        2630 non-null   object
# dtypes: float64(14), int64(4), object(5)
# memory usage: 472.7+ KB

# %%
total_df_saved = total_df.copy()

# %%
total_df = total_df_saved.copy()

# %%
if 'Club' in total_df.columns:
    total_df.insert(1, "Club", total_df.pop("Club"))
else:
    total_df.insert(1, "Club", "")

# remove the club column
# total_df.drop(columns=['Club'], inplace=True)

#drop all rows with that have NaN values in "Sh"
# total_df.dropna(subset=['Sh'], inplace=True)

# %%
total_df.info()
total_df.rename(columns={'': 'Club'}, inplace=True)
# aceesss the sot/90 column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   (Unnamed: 0_level_0, Player)    2630 non-null   object
#  1   (Club, )                        2630 non-null   object
#  2   (Unnamed: 1_level_0, Nation)    2628 non-null   object
#  3   (Unnamed: 2_level_0, Pos)       2630 non-null   object
#  4   (Unnamed: 3_level_0, Age)       2630 non-null   float64
#  5   (Unnamed: 4_level_0, 90s)       2630 non-null   float64
#  6   (Performance, CrdY)             2630 non-null   int64
#  7   (Performance, CrdR)             2630 non-null   int64
#  8   (Performance, 2CrdY)            2630 non-null   int64
#  9   (Performance, Fls)              2611 non-null   float64
#  10  (Performance, Fld)              2611 non-null   float64
#  11  (Performance, Off)              2611 non-null   float64
#  12  (Performance, Crs)              2611 non-null   float64
#  13  (Performance, Int)              2611 non-null   float64
#  14  (Performance, TklW)             2611 non-null   float64
#  15  (Performance, PKwon)            2609 non-null   float64
#  16  (Performance, PKcon)            2609 non-null   float64
#  17  (Performance, OG)               2630 non-null   int64
#  18  (Performance, Recov)            2541 non-null   float64
#  19  (Aerial Duels, Won)             2541 non-null   float64
#  20  (Aerial Duels, Lost)            2541 non-null   float64
#  21  (Aerial Duels, Won%)            2463 non-null   float64
#  22  (Unnamed: 21_level_0, Matches)  2630 non-null   object
# dtypes: float64(14), int64(4), object(5)
# memory usage: 472.7+ KB

# %%
total_df = total_df.iloc[:, :-1]

# %%
total_df.columns = total_df.columns.get_level_values(1)

# %%
# cleaning Nation values so only the uppercase string will be kept
total_df['Nation'] = total_df['Nation'].str.split().str[1]

# %%
print(total_df.columns[total_df.columns.duplicated()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(total_df.columns[total_df.columns.duplicated()])
#
# NameError: name 'total_df' is not defined

# %%
total_df.to_csv("t5_leagues_players_misc.csv", index=False)
