# %%
import pandas as pd
import numpy as np
from scipy.stats import rankdata

# Einlesen der CSV-Datei
df = pd.read_csv('../op_players_list.csv')

# Filtern der Spieler mit über 450 Minuten Spielzeit
df = df[df['Minutes played'] > 450]

# Funktionen zur Berechnung pro 90 Minuten Werte
def per_90(stat, minutes):
    return (stat / minutes) * 90 if minutes > 0 else 0

# Berechnung der pro 90 Minuten Werte für alle relevanten Statistiken
for col in df.columns:
    if col not in ['Player', 'Nation', 'Age', 'Club', 'Position', 'Minutes played', '90 minutes played']:
        df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)

# Berechnung der Perzentile für jede Position
positions = df['Position'].unique()
percentiles = {}

for pos in positions:
    pos_df = df[df['Position'] == pos]
    percentiles[pos] = pos_df.copy()
    
    for col in df.columns:
        if col.endswith('per 90'):
            percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100

# Zusammenführen der Perzentile in den ursprünglichen DataFrame
for pos, pos_df in percentiles.items():
    for col in pos_df.columns:
        if col.endswith('per 90 percentile'):
            df.loc[df['Position'] == pos, col] = pos_df[col]

# Filtern der Daten für Virgil van Dijk
van_dijk = df[df['Player'] == 'Raheem Sterling'].iloc[0]

# Identifizierung der Kategorien mit den höchsten Perzentilen für Virgil van Dijk
van_dijk_stats = van_dijk.filter(like='percentile')
top_stats = van_dijk_stats.sort_values(ascending=False).head(20)

print("Top Kategorien für Virgil van Dijk:")
print(top_stats)
# Out:
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col} per 90'] = df.apply(lambda row: per_90(row[col], row['Minutes played']), axis=1)
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   percentiles[pos][f'{col} percentile'] = rankdata(pos_df[col], method='average') / len(pos_df) * 100
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# /var/folders/zx/_6c6bk211jg76gggnhvmrt900000gn/T/ipykernel_63042/2488298345.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['Position'] == pos, col] = pos_df[col]
# Top Kategorien für Virgil van Dijk:
# Touches in attacking penalty area per 90 percentile            99.771689
# Progressive Passes Received per 90 percentile                  99.315068
# Fouls drawn that led to a goal per 90 percentile               99.315068
# Carries into penalty area per 90 percentile                    98.858447
# Goal creating actions per 90 percentile                        98.630137
# Successful Take-Ons that led to a shot per 90 percentile       98.630137
# Goal creating actions by live-ball passes per 90 percentile    97.945205
# Dispossessed per 90 percentile                                 97.945205
# Shot creating actions per 90 percentile                        97.260274
# Touches in attacking 1/3 per 90 percentile                     97.031963
# Times ball carried with feet per 90 percentile                 96.803653
# Successful take ons per 90 percentile                          96.347032
# Shot creating actions by live-ball passes per 90 percentile    95.890411
# Progressive Carries per 90 percentile                          95.890411
# Take ons attempted per 90 percentile                           95.890411
# Times tackled during take on per 90 percentile                  95.43379
# Passes received per 90 percentile                              95.205479
# Successful Take-Ons that led to a goal per 90 percentile       95.205479
# Carries into final 1/3 per 90 percentile                       94.520548
# Progressive moved ball distance per 90 percentile              94.292237
# Name: 3, dtype: object
